# %%
import folium

# Data from the table
data = [
    {"name": "Veterník", "latitude": 48.816216, "longitude": 17.230180,
        "altitude": 310, "height": 22.0, "type": "Typ 1"},
    {"name": "Míšek", "latitude": 48.575736, "longitude": 17.424016,
        "altitude": 419, "height": 26.0, "type": "Typ 2"},
    {"name": "Veľká Márovka", "latitude": 48.598521, "longitude": 21.429493,
        "altitude": 678, "height": 36.6, "type": "Typ 3"},
    {"name": "Vápenná", "latitude": 48.263751, "longitude": 18.473403,
        "altitude": 344, "height": 36.6, "type": "Typ 3"},
    {"name": "Tupý Vrch", "latitude": 48.113311, "longitude": 18.925196,
        "altitude": 224, "height": 36.6, "type": "Typ 3"},
    {"name": "Magoš (Slavec)", "latitude": 48.588376, "longitude": 20.493644,
     "altitude": 671, "height": 36.6, "type": "Typ 3"},
    {"name": "Moldava nad Bodvou", "latitude": 48.593039,
        "longitude": 20.996358, "altitude": 200, "height": 36.6, "type": "Typ 3"},
    {"name": "Búdkovce", "latitude": 48.619016, "longitude": 21.909067,
        "altitude": 105, "height": 36.6, "type": "Typ 3"},
    {"name": "Rimavská Sobota", "latitude": 48.370542, "longitude": 20.012431,
        "altitude": 212, "height": 52.7, "type": "Typ 4"},
    {"name": "Brody", "latitude": 48.344617, "longitude": 17.767980,
        "altitude": 244, "height": 36.6, "type": "Typ 3"},
    {"name": "Detvianska Huta", "latitude": 48.536794, "longitude": 19.591591,
        "altitude": 918, "height": 36.6, "type": "Typ 3"}
]

# Colors for each type of construction
colors = {
    "Typ 1": "darkblue",
    "Typ 2": "darkgreen",
    "Typ 3": "darkred",
    "Typ 4": "darkpurple"
}

# Create a map centered around the first coordinate
m = folium.Map(location=[48.816216, 17.230180], zoom_start=7)

# Add markers to the map
for item in data:
    folium.Marker(
        location=[item["latitude"], item["longitude"]],
        popup=f'{item["name"]} ({item["type"]})\nAltitude: {
            item["altitude"]} m\nHeight: {item["height"]} m',
        icon=folium.Icon(color=colors[item["type"]])
    ).add_to(m)

# Save the map to an HTML file
m.save('map.html')

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Data from the table
data = [
    {"name": "Veterník", "latitude": 48.816216, "longitude": 17.230180,
        "altitude": 310, "height": 22.0, "type": "Typ 1"},
    {"name": "Míšek", "latitude": 48.575736, "longitude": 17.424016,
        "altitude": 419, "height": 26.0, "type": "Typ 2"},
    {"name": "Veľká Márovka", "latitude": 48.598521, "longitude": 21.429493,
        "altitude": 678, "height": 36.6, "type": "Typ 3"},
    {"name": "Vápenná", "latitude": 48.263751, "longitude": 18.473403,
        "altitude": 344, "height": 36.6, "type": "Typ 3"},
    {"name": "Tupý Vrch", "latitude": 48.113311, "longitude": 18.925196,
        "altitude": 224, "height": 36.6, "type": "Typ 3"},
    {"name": "Magoš (Slavec)", "latitude": 48.588376, "longitude": 20.493644,
     "altitude": 671, "height": 36.6, "type": "Typ 3"},
    {"name": "Moldava nad Bodvou", "latitude": 48.593039,
        "longitude": 20.996358, "altitude": 200, "height": 36.6, "type": "Typ 3"},
    {"name": "Búdkovce", "latitude": 48.619016, "longitude": 21.909067,
        "altitude": 105, "height": 36.6, "type": "Typ 3"},
    {"name": "Rimavská Sobota", "latitude": 48.370542, "longitude": 20.012431,
        "altitude": 212, "height": 52.7, "type": "Typ 4"},
    {"name": "Brody", "latitude": 48.344617, "longitude": 17.767980,
        "altitude": 244, "height": 36.6, "type": "Typ 3"},
    {"name": "Detvianska Huta", "latitude": 48.536794, "longitude": 19.591591,
        "altitude": 918, "height": 36.6, "type": "Typ 3"}
]

# Colors for each type of construction
colors = {
    "Typ 1": "black",
    "Typ 2": "black",
    "Typ 3": "black",
    "Typ 4": "black"
}

# Create a map centered around the first coordinate
m = folium.Map(location=[48.816216, 17.230180], zoom_start=7, tiles="Cartodb Positron")

# Add markers to the map
for item in data:
    folium.Marker(
        location=[item["latitude"], item["longitude"]],
        popup=f'{item["name"]} ({item["type"]})\nAltitude: {
            item["altitude"]} m\nHeight: {item["height"]} m',
        icon=folium.Icon(color=colors[item["type"]])
    ).add_to(m)

# Save the map to an HTML file
m.save('map.html')

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
