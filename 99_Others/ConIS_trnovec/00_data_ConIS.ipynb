# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime
import pytz

# %%
db = "sim-bridge"
coll = "PRJ-23"

mongo_URI = "mongodb+srv://monitor:kundrovejmamka@xerxes.57jmr.mongodb.net/alfa?retryWrites=true&w=majority"
cluster = MongoClient(mongo_URI)

db = cluster[db]
collection = db[coll]

# %%
# Find documents where "measurements" exists and "meta" does not
documents = collection.find()

# Initialize an empty list to store the documents
document_list = []

# Iterate through the cursor and store documents in the list
for document in documents:
    document_list.append(document)

# Create a DataFrame from the list of documents
df2 = pd.DataFrame(document_list)

# %%
df = df2.copy()

# %%
df2.iloc[0]
# Out:
# _id                              66fd8e641475ea3880611d56
# meta    {'power': {'battery': {'V': 4.225999832}}, 'bo...
# fft     [{'f': 57.03125, 'a': 127.7456207}, {'f': 57.2...
# Name: 0, dtype: object

# %%
from bson import ObjectId
import pandas as pd

# Function to convert ObjectId to timestamp


def objectid_to_time(objectid):
    return ObjectId(objectid).generation_time.isoformat()


# Create a new DataFrame by iterating through df2
data = []
for index, row in df2.iterrows():
    # Extract time from _id
    time = objectid_to_time(row['_id'])

    # Unpack the fft list into individual entries with 'f' and 'a'
    fft_data = {i: entry for i, entry in enumerate(row['fft'])}

    # Add the time field to the fft data
    fft_data['time'] = time

    # Append to the list
    data.append(fft_data)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Move 'time' to the first column
df = df[['time'] + [col for col in df.columns if col != 'time']]

# Display the DataFrame
df
# Out:
#                            time                                     0  \
# 0     2024-10-02T18:18:12+00:00     {'f': 57.03125, 'a': 127.7456207}
# 1     2024-10-02T18:28:54+00:00    {'f': 5.6640625, 'a': 15.26204872}
# 2     2024-10-02T18:32:12+00:00    {'f': 0.9765625, 'a': 4.386540413}
# 3     2024-10-02T18:38:31+00:00       {'f': 57.03125, 'a': 16.576931}
# 4     2024-10-02T18:40:11+00:00  {'f': 64.99023438, 'a': 105.7667694}
# ...                         ...                                   ...
# 1706  2024-10-20T12:27:16+00:00  {'f': 14.30664063, 'a': 0.135566175}
# 1707  2024-10-20T12:42:11+00:00   {'f': 41.45507813, 'a': 0.13271755}
# 1708  2024-10-20T12:57:07+00:00    {'f': 1.3671875, 'a': 0.138668269}
# 1709  2024-10-20T13:12:02+00:00   {'f': 11.1328125, 'a': 0.131460235}
# 1710  2024-10-20T13:26:59+00:00   {'f': 15.0390625, 'a': 0.135547221}
#
#                                          1  \
# 0      {'f': 57.2265625, 'a': 34.87096405}
# ...

# %%
import pandas as pd

# Function to process a row: filter and sort dictionaries


def sort_row_by_frequency(row):
    # Extract only valid dictionaries (with both 'f' and 'a' keys)
    valid_dicts = {key: value for key, value in row.items() if isinstance(
        value, dict) and 'f' in value and 'a' in value}

    # Sort the valid dictionaries by the 'f' key
    sorted_valid_dicts = sorted(valid_dicts.items(), key=lambda x: x[1]['f'])

    # Create a new row, starting with 'time', and fill the columns with sorted dictionaries
    sorted_row = {'time': row['time']}

    # Put sorted valid dictionaries back, maintaining the order
    sorted_row.update({i: d[1] for i, d in enumerate(sorted_valid_dicts)})

    # Fill the remaining columns with NaN if the dictionary was invalid or dropped
    for i in range(len(row) - 1):  # Exclude 'time'
        if i not in sorted_row:
            sorted_row[i] = pd.NA

    return pd.Series(sorted_row)


# Apply the function to each row in the DataFrame
df = df.apply(sort_row_by_frequency, axis=1)

df
# Out:
#                            time                                     0  \
# 0     2024-10-02T18:18:12+00:00  {'f': 55.81054688, 'a': 1.201637268}
# 1     2024-10-02T18:28:54+00:00  {'f': 0.048828125, 'a': 13.11343956}
# 2     2024-10-02T18:32:12+00:00   {'f': 0.09765625, 'a': 3.862884998}
# 3     2024-10-02T18:38:31+00:00  {'f': 0.048828125, 'a': 0.142961875}
# 4     2024-10-02T18:40:11+00:00  {'f': 63.57421875, 'a': 0.606832385}
# ...                         ...                                   ...
# 1706  2024-10-20T12:27:16+00:00  {'f': 0.048828125, 'a': 0.080322564}
# 1707  2024-10-20T12:42:11+00:00  {'f': 5.712890625, 'a': 0.097064406}
# 1708  2024-10-20T12:57:07+00:00  {'f': 0.146484375, 'a': 0.130122557}
# 1709  2024-10-20T13:12:02+00:00  {'f': 0.146484375, 'a': 0.101481684}
# 1710  2024-10-20T13:26:59+00:00   {'f': 0.048828125, 'a': 0.11613562}
#
#                                          1  \
# 0       {'f': 55.859375, 'a': 1.516067266}
# ...

# %%
# Drop columns where all values are NaN
df = df.dropna(axis=1, how='all')

# %%
df.iloc[461]
# Out:
# time    2024-10-07T10:57:03+00:00
# 0                {'f': 0, 'a': 0}
# 1                {'f': 0, 'a': 0}
# 2                {'f': 0, 'a': 0}
# 3                {'f': 0, 'a': 0}
#                   ...
# 75                           <NA>
# 76                           <NA>
# 77                           <NA>
# 78                           <NA>
# 79                           <NA>
# Name: 461, Length: 81, dtype: object

# %%
import plotly.graph_objs as go
import ipywidgets as widgets
from ipywidgets import interact
import pandas as pd
from IPython.display import clear_output, display

# Define a function to update the plot based on the row index and number of previous spectrums


def update_plot(row_index, previous_spectrums):
    # Clear the previous output
    clear_output(wait=True)

    # Create the scatter plot
    fig = go.Figure()

    # Plot the previous spectrums if possible
    for i in range(1, previous_spectrums + 1):
        if row_index - i >= 0:
            prev_row = df.iloc[row_index - i]
            prev_frequencies = []
            prev_amplitudes = []
            for j in range(30):  # Assuming there are 30 spectrum columns (0-29)
                spectrum_data = prev_row[j]
                prev_frequencies.append(spectrum_data['f'])
                prev_amplitudes.append(spectrum_data['a'])

            # Add the previous spectrum data as a scatter plot with smaller markers and alpha
            fig.add_trace(go.Scatter(
                x=prev_frequencies,
                y=prev_amplitudes,
                mode='markers',
                # Same color, smaller markers with alpha
                marker=dict(size=4, opacity=0.7, color='blue'),
                name=f'Previous Spectrum - Row {row_index - i}'
            ))

    # Extract the frequencies and amplitudes from the specified row
    frequencies = []
    amplitudes = []

    row = df.iloc[row_index]
    for i in range(71):  # Assuming there are 30 spectrum columns (0-29)
        spectrum_data = row[i]
        frequencies.append(spectrum_data['f'])
        amplitudes.append(spectrum_data['a'])

    # Get the 'time' value from the row
    time_value = row['time']

    # Add the current spectrum data as a scatter plot
    fig.add_trace(go.Scatter(
        x=frequencies,
        y=amplitudes,
        mode='markers',
        marker=dict(size=6, color='blue'),  # Same color for current markers
        name=f'Spectrum - Row {row_index}'
    ))

    # Update the layout of the plot
    fig.update_layout(
        title=f"Frequency vs Amplitude Scatter Plot",
        xaxis_title="Frequency (Hz)",
        yaxis_title="Amplitude",
        showlegend=False,
        # yaxis=dict(range=[0, 2.5])
        xaxis=dict(range=[0, 100]),  # Set x-axis limits from 0 to 100
    )

    # Add the 'time' value in the bottom-right corner
    fig.add_annotation(
        xref="paper", yref="paper",
        x=1, y=-0.125,  # Position at the bottom-right
        text=f"{time_value}",
        showarrow=False,
        font=dict(size=12),
        xanchor='right',
        yanchor='bottom'
    )

    # Show the plot
    display(fig)


# # Create a slider widget for selecting the row index
# row_slider = widgets.IntSlider(value=500, min=0, max=len(
#     df) - 1, step=1, description='Row Index:', layout=widgets.Layout(width='90%'))

# Create a text input widget for selecting the number of previous spectrums to plot
row_slider = widgets.BoundedIntText(
    value=445, min=0, max=len(
        df) - 1, step=1, description='Row Index:')

# Create a text input widget for selecting the number of previous spectrums to plot
previous_spectrums_input = widgets.BoundedIntText(
    value=100, min=0, max=2000, step=1, description='Previous Spectrums:')

# Use the interact function to update the plot whenever the inputs change
interact(update_plot, row_index=row_slider,
         previous_spectrums=previous_spectrums_input)
# Out:
# interactive(children=(BoundedIntText(value=445, description='Row Index:', max=1710), BoundedIntText(value=100,…
# <function __main__.update_plot(row_index, previous_spectrums)>

# %%
495 - 441
# Out:
# 54

# %%
def plot_spectrum(df, row, color='blue', column_range=(0, 5), local_time=""):
    # Extract the data from the specified row and columns
    data = df.iloc[row][list(range(column_range[0], column_range[1] + 1))]

    # Extract frequencies and amplitudes
    frequencies = [d['f']
                   for d in data if isinstance(d, dict) and 'f' in d and 'a' in d]
    amplitudes = [d['a']
                  for d in data if isinstance(d, dict) and 'f' in d and 'a' in d]

    # Create the plot
    fig = go.Figure(data=go.Scatter(x=frequencies, y=amplitudes,
                    mode='markers', marker=dict(color=color)))
    
    # Update the layout of the plot
    fig.update_layout(
        title=f"{local_time.strftime('%d. %b %y, %H:%M')}",
        xaxis_title="Frekvencia (Hz)",
        yaxis_title="Amplitúda",
        margin=dict(l=60, r=50, t=50, b=50),
        showlegend=False,
        # yaxis=dict(range=[0, 2.5])
        xaxis=dict(range=[0, 100]),  # Set x-axis limits from 0 to 100
    )

    # Show the plot
    fig.show()

# %%
row = 451
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(7))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

row_data = df.iloc[row][list(range(7, 22))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"II: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#FFB347',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 11:51
# I: 	4.17 Hz
# II: 	7.15 Hz

# %%
row = 468
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(23))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

row_data = df.iloc[row][list(range(23, 57))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"II: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#FF6961',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 13:34
# I: 	39.05 Hz
# II: 	46.66 Hz

# %%
row = 470
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[470][list(range(6))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#77DD77',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 13:45
# I: 	9.36 Hz

# %%
row = 471
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(5))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

row_data = df.iloc[row][list(range(5, 25))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"II: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#F49AC2',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 13:48
# I: 	3.40 Hz
# II: 	7.58 Hz

# %%
row = 473
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(3))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#394938',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 14:08
# I: 	3.64 Hz

# %%
row = 489
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(6))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

row_data = df.iloc[row][list(range(6, 30))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"II: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#9b442a',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 16:04
# I: 	4.12 Hz
# II: 	7.46 Hz

# %%
row = 495
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(8))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

row_data = df.iloc[row][list(range(8, 22))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"II: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#476086',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 16:26
# I: 	3.45 Hz
# II: 	7.45 Hz

# %%
row = 441
local_time = datetime.fromisoformat(df.iloc[row]["time"]).astimezone(
    pytz.timezone('Europe/Bratislava'))
print(local_time.strftime('%d. %b %y, %H:%M'))

row_data = df.iloc[row][list(range(6))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"I: \t{weighted_mean:.2f} Hz")

row_data = df.iloc[row][list(range(6, 21))]

weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

weighted_mean = weighted_sum / sum_of_weights

print(f"II: \t{weighted_mean:.2f} Hz")

plot_spectrum(df, row=row, color='#19D3F3',
              column_range=(0, 70), local_time=local_time)
# Out:
# 07. Oct 24, 11:03
# I: 	5.61 Hz
# II: 	7.64 Hz

# %%
for index, value in df.iloc[441].items():
    print(f"{index}: {value}")
# Out:
# time: 2024-10-07T09:03:31+00:00
# 0: {'f': 5.46875, 'a': 0.938584507}
# 1: {'f': 5.517578125, 'a': 1.002795935}
# 2: {'f': 5.56640625, 'a': 1.19218874}
# 3: {'f': 5.615234375, 'a': 1.317205429}
# 4: {'f': 5.6640625, 'a': 1.117293596}
# 5: {'f': 5.76171875, 'a': 1.311519861}
# 6: {'f': 6.34765625, 'a': 0.959602237}
# 7: {'f': 6.689453125, 'a': 1.149694085}
# 8: {'f': 6.8359375, 'a': 1.106520176}
# 9: {'f': 6.884765625, 'a': 1.135064125}
# 10: {'f': 6.93359375, 'a': 1.312033296}
# 11: {'f': 7.568359375, 'a': 1.091784716}
# 12: {'f': 7.763671875, 'a': 2.264555931}
# 13: {'f': 7.8125, 'a': 0.992487192}
# 14: {'f': 7.861328125, 'a': 0.945308387}
# 15: {'f': 7.91015625, 'a': 1.64556241}
# 16: {'f': 8.0078125, 'a': 1.523064852}
# 17: {'f': 8.056640625, 'a': 1.568696618}
# 18: {'f': 8.10546875, 'a': 1.668632269}
# 19: {'f': 8.154296875, 'a': 1.037660956}
# 20: {'f': 8.984375, 'a': 1.111774445}
# 21: {'f': 9.08203125, 'a': 0.924319983}
# 22: {'f': 29.4921875, 'a': 1.343744278}
# ...

# %% [markdown]
# 495 posledné zrejme
# 439 prvé

# %%
from bson import ObjectId
import pytz

# Example ObjectId
object_id = df2.iloc[445]["_id"]

# Convert to timestamp (UTC)
timestamp_utc = object_id.generation_time

# Convert to a specific timezone (e.g., 'Europe/Bratislava')
timezone = pytz.timezone('Europe/Bratislava')
timestamp_local = timestamp_utc.astimezone(timezone)

# Print both times
print("UTC Time:", timestamp_utc)
print("Local Time:", timestamp_local)
# Out:
# UTC Time: 2024-10-07 09:07:23+00:00
# Local Time: 2024-10-07 11:07:23+02:00

# %%
495 - 441
# Out:
# 54

# %%
df_fft = df.iloc[441:496].copy().reset_index(drop=True)

# %%
def create_plotted_data(df):
    plotted_dicts = []

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        # Iterate over each column in the row, except the 'time' column
        for col in row.index:
            if isinstance(row[col], dict) and 'f' in row[col] and 'a' in row[col]:
                freq = row[col]['f']
                amp = row[col]['a']
                plotted_dicts.append({'f': freq, 'a': amp})

    return plotted_dicts


# Call the function to get the list of plotted dictionaries
plotted_data = create_plotted_data(df_fft)

# %%
plotted_data = sorted(plotted_data, key=lambda x: x['f'])

plotted_data = [d for d in plotted_data if d['a'] >= 0.2]

for i in range(len(plotted_data)):
    print(i, plotted_data[i])

# %%
import plotly.graph_objects as go

def plot_filtered_spectrum(plotted_data):
    # Extract frequencies and amplitudes from plotted_data
    frequencies = [d['f'] for d in plotted_data]
    amplitudes = [d['a'] for d in plotted_data]

    # Create a scatter plot
    fig = go.Figure(data=go.Scatter(x=frequencies, y=amplitudes,
                    mode='markers', marker=dict(color='#19D3F3')))

    # Update the layout
    fig.update_layout(
        title="Spectrum: Frequency vs Amplitude",
        xaxis_title="Frequency (Hz)",
        yaxis_title="Amplitude",
        showlegend=False
    )

    # Show the plot
    fig.show()

plot_filtered_spectrum(plotted_data)

# %%
def calculate_weighted_means(plotted_data, pairs):
    results = []

    for pair in pairs:
        start_index = pair['s']
        end_index = pair['e']

        # Extract the relevant portion of plotted_data for weighted mean calculation
        # +1 to include the end index
        row_data = plotted_data[start_index:end_index+1]

        # Calculate the weighted sum and sum of weights
        weighted_sum = sum(d['a'] * d['f'] for d in row_data)
        sum_of_weights = sum(d['a'] for d in row_data)

        # Calculate the weighted mean
        if sum_of_weights != 0:
            weighted_mean = weighted_sum / sum_of_weights
            results.append(weighted_mean)
            print(f"Weighted mean for indices {start_index} to {
                  end_index}: {weighted_mean:.2f} Hz")
        else:
            results.append(None)
            print(f"Weighted mean for indices {start_index} to {
                  end_index}: No valid data (sum of weights is zero)")

    return results

# %%
pairs = [{'s': 0, 'e': 29}, {'s': 30, 'e': 185}, {'s': 186, 'e': 251}, {
    's': 252, 'e': 2797}, {'s': 2798, 'e': 3367}, {'s': 3368, 'e': 3563}, {
    's': 3564, 'e': 3621}, {'s': 3630, 'e': 3694}, {'s': 3698, 'e': 3717}]

weighted_means = calculate_weighted_means(plotted_data, pairs)
# Out:
# Weighted mean for indices 0 to 29: 3.92 Hz
# Weighted mean for indices 30 to 185: 7.74 Hz
# Weighted mean for indices 186 to 251: 11.47 Hz
# Weighted mean for indices 252 to 2797: 43.92 Hz
# Weighted mean for indices 2798 to 3367: 63.32 Hz
# Weighted mean for indices 3368 to 3563: 70.04 Hz
# Weighted mean for indices 3564 to 3621: 75.54 Hz
# Weighted mean for indices 3630 to 3694: 89.37 Hz
# Weighted mean for indices 3698 to 3717: 99.11 Hz

# %%
# Define the range of indices you want to use from plotted_data (e.g., 7 to 21)
start_index = 0
end_index = 29

# Extract the relevant portion of plotted_data for weighted mean calculation
row_data = plotted_data[start_index:end_index]

# Calculate the weighted sum and sum of weights
weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

# Calculate the weighted mean
if sum_of_weights != 0:
    weighted_mean = weighted_sum / sum_of_weights
else:
    weighted_mean = None  # Handle division by zero case

# Print the result
if weighted_mean is not None:
    print(f"II: \t{weighted_mean:.2f} Hz")
else:
    print("No valid data to calculate the weighted mean.")
# Out:
# II: 	3.89 Hz

# %%
pairs = [{'s': 0, 'e': 29}, {'s': 30, 'e': 45}, {'s': 76, 'e': 92}]

# %%
# Define the range of indices you want to use from plotted_data (e.g., 7 to 21)
start_index = 0
end_index = 29

# Extract the relevant portion of plotted_data for weighted mean calculation
row_data = plotted_data[start_index:end_index]

# Calculate the weighted sum and sum of weights
weighted_sum = sum(d['a'] * d['f'] for d in row_data)
sum_of_weights = sum(d['a'] for d in row_data)

# Calculate the weighted mean
if sum_of_weights != 0:
    weighted_mean = weighted_sum / sum_of_weights
else:
    weighted_mean = None  # Handle division by zero case

# Print the result
if weighted_mean is not None:
    print(f"II: \t{weighted_mean:.2f} Hz")
else:
    print("No valid data to calculate the weighted mean.")
