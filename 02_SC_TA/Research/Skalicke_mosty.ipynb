# %%
import pandas as pd

# DOMA
# Define the file path
nodes_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
roads_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Roads_processed.csv"
bridges_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_processed.csv"
bridges_selected_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_selected.csv"
survey_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\surveys\Survey.csv"


# # Práca
# # Define the file path
# nodes_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
# roads_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Roads_processed.csv"
# bridges_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Bridges_processed.csv"
# bridges_selected_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Bridges_selected.csv"
# survey_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\surveys\Survey.csv"

# Load the CSV data into a DataFrame
df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')
df_bridges_all = pd.read_csv(bridges_path, encoding='utf-8', delimiter=',')
df_bridges_sel = pd.read_csv(
    bridges_selected_path, encoding='utf-8', delimiter=',')
df_survey = pd.read_csv(survey_path, encoding='utf-8', delimiter=',')
# Out:
# C:\Users\Doktor\AppData\Local\Temp\ipykernel_28308\4094816067.py:21: DtypeWarning: Columns (5,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
# C:\Users\Doktor\AppData\Local\Temp\ipykernel_28308\4094816067.py:22: DtypeWarning: Columns (10,11,12,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')

# %%
df_bridges_all['Dĺžka_premostenia'] = pd.to_numeric(
    df_bridges_all['Dĺžka_premostenia'], errors='coerce')

# %%
# Filter bridges in the Nitra region with Trieda_PK as "cesta I. triedy" or "cesta II. triedy"
filtered_bridges = df_bridges_all[
    (df_bridges_all['Okres'] == "Skalica") &
    (df_bridges_all['Trieda_PK'] != "cesta I. triedy")
]

# Display the filtered DataFrjjjame
filtered_bridges.shape
# Out:
# (35, 51)

# %%
df_bridges_all.columns
# Out:
# Index(['ID_mosta', 'Trieda_PK', 'Číslo_PK', 'Most_DC', 'Názov_mosta', 'ID_DC',
#        'správcovské_číslo', 'Zemepisná_dĺžka', 'Zemepisná_šírka', 'Výška',
#        'Druh_konštrukcie', 'Material', 'Normálna_zaťažiteľnosť',
#        'Výhradná_zaťažiteľnosť_t', 'Výnimočná_zaťažiteľnosť_t',
#        'Spôsob_stanovenia', 'Predmet_premostenia', 'Rok_postavenia',
#        'Zaťažovacia_trieda_STN', 'Počet_otvorov', 'Dĺžka_premostenia',
#        'Dĺžka_nosnej_konštrukcie_m', 'Volná_šírka_mosta',
#        'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
#        'Plocha_mosta_m2', 'Vlastník_úseku', 'Správca_úseku', 'Okres',
#        'Smer_úseku', 'Typ_úseku', 'Počiatočný_uzol', 'Koncový_uzol', 'úsek_ID',
#        'úsekové_staničenie_začiatku_DC_m',
#        'Kilometrovníkové_staničenie_začiatku_DC_km',
#        'Kumulatívne_staničenie_začiatku_DC_km', 'Poradie', 'Kraj', 'n_2012',
#        'n_2013', 'n_2014', 'n_2015', 'n_2016', 'n_2017', 'n_2018', 'n_2019',
#        'n_2020', 'n_2021', 'n_2022', 'n_2023'],
#       dtype='object')

# %%
filtered_bridges[["ID_mosta", "Názov_mosta", "n_2023"]]
# Out:
#      ID_mosta                                        Názov_mosta  n_2023
# 1825    M1644     425-031 Most cez rieku Morava pri obci Brodské       7
# 1826    M1523     425-032 Most cez potok Haďmáš pri obci Brodské       4
# 1827     M932  426A-001 Most cez Skalický potok a poľnú cestu...       4
# 1828     M755  426A-002 Most nad poľnou cestou pred mestom Sk...       3
# 1829    M4061  426-017 Most cez Starohorský potok za mestom S...       4
# 1830    M6492  426-018 Most cez Starohorský potok za mestom S...       4
# 1831    M7178    426-019 Most cez kanál medzi Skalicou a Holíčom       4
# 1832     M433  426-021 Most cez potok Chvojnica pred mestom H...       6
# 3240     M972  590-010 Most cez Unínsky potok v obci Petrova Ves       4
# 3241    M7762  590-011 Most cez Unínsky potok za obcou Petrov...       6
# 3242    M5561  590-012 Most cez Radimovský potok pred mestom ...       5
# 4219    M1446  0518-001 Most cez Mokrohájsky potok v obci Pri...       3
# 4220    M1900          0519-001 Most cez potok Chvojnicu Trnovec       3
# 4221     M406  0519-003 Most cez potok Chvojnica Popudinské M...       4
# 4222    M5388             0519-004 Most cez potok v obci Dubovce       4
# 4223    M1538            0519 -005 Most cez potok v obci Dubovce       4
# 4224    M5130  0519-006 Most cez potok Chvojnica za obcou Dub...       1
# 4226    M7579  05110-004 Most cez Pavlovský potok pred obcou ...       4
# 4227    M3991   05110-005 Most cez potok Chvojnica v obci Vieska       5
# 4228    M6503  05110-006 Most cez Chropovský potok v obci Rad...       4
# 4229    M1960     05110-007 Most cez Koválovecký potok Radošovce       4
# 4233    M2104     05113-001 Most cez Koválovecký potok Koválovec       4
# 5206    M4758     4265-001 Most cez odpad v úseku Vrádište-Holíč       4
# 5207    M7437  426007-001 Most cez potok Haďmáš pred obcou Br...       3
# 5208    M3490  4269-001 Most cez Zlatnický potok za mestom Sk...       3
# 5209    M1314  4269-002 Most cez Zlatnický potok za mestom Sk...       3
# 5270    M2412         5003-001 Most cez potok v obci Petrova Ves       4
# 5271    M3782            5003-004 Most cez odpad v obci Letničie       3
# 5272      M10         5006-001Most cez Leský potok za obcou Unín       4
# 5273     M277         5007-001 Most cez Radimovský potok Radimov       4
# 5274    M6452        5007-002 Most cez Unínsky potok v obci Unín       3
# 7527    M1167                                          Nezistený       2
# 7528    M6553                                Most Brodské - Kúty       4
# 7585     M567              426-016 Most cez Horský potok Skalica       4
# 8124    M9680                          Most cez potok CHovojnica       4

# %%
filtered_bridges[["ID_mosta", "Názov_mosta", "n_2023"]], filtered_bridges["n_2023"].value_counts()
# Out:
# (     ID_mosta                                        Názov_mosta  n_2023
#  1825    M1644     425-031 Most cez rieku Morava pri obci Brodské       7
#  1826    M1523     425-032 Most cez potok Haďmáš pri obci Brodské       4
#  1827     M932  426A-001 Most cez Skalický potok a poľnú cestu...       4
#  1828     M755  426A-002 Most nad poľnou cestou pred mestom Sk...       3
#  1829    M4061  426-017 Most cez Starohorský potok za mestom S...       4
#  1830    M6492  426-018 Most cez Starohorský potok za mestom S...       4
#  1831    M7178    426-019 Most cez kanál medzi Skalicou a Holíčom       4
#  1832     M433  426-021 Most cez potok Chvojnica pred mestom H...       6
#  3240     M972  590-010 Most cez Unínsky potok v obci Petrova Ves       4
#  3241    M7762  590-011 Most cez Unínsky potok za obcou Petrov...       6
#  3242    M5561  590-012 Most cez Radimovský potok pred mestom ...       5
#  4219    M1446  0518-001 Most cez Mokrohájsky potok v obci Pri...       3
#  4220    M1900          0519-001 Most cez potok Chvojnicu Trnovec       3
#  4221     M406  0519-003 Most cez potok Chvojnica Popudinské M...       4
#  4222    M5388             0519-004 Most cez potok v obci Dubovce       4
#  4223    M1538            0519 -005 Most cez potok v obci Dubovce       4
#  4224    M5130  0519-006 Most cez potok Chvojnica za obcou Dub...       1
#  4226    M7579  05110-004 Most cez Pavlovský potok pred obcou ...       4
#  4227    M3991   05110-005 Most cez potok Chvojnica v obci Vieska       5
#  4228    M6503  05110-006 Most cez Chropovský potok v obci Rad...       4
#  4229    M1960     05110-007 Most cez Koválovecký potok Radošovce       4
#  4233    M2104     05113-001 Most cez Koválovecký potok Koválovec       4
#  5206    M4758     4265-001 Most cez odpad v úseku Vrádište-Holíč       4
#  5207    M7437  426007-001 Most cez potok Haďmáš pred obcou Br...       3
#  5208    M3490  4269-001 Most cez Zlatnický potok za mestom Sk...       3
#  5209    M1314  4269-002 Most cez Zlatnický potok za mestom Sk...       3
#  5270    M2412         5003-001 Most cez potok v obci Petrova Ves       4
#  5271    M3782            5003-004 Most cez odpad v obci Letničie       3
#  5272      M10         5006-001Most cez Leský potok za obcou Unín       4
#  5273     M277         5007-001 Most cez Radimovský potok Radimov       4
#  5274    M6452        5007-002 Most cez Unínsky potok v obci Unín       3
#  7527    M1167                                          Nezistený       2
#  7528    M6553                                Most Brodské - Kúty       4
#  7585     M567              426-016 Most cez Horský potok Skalica       4
#  8124    M9680                          Most cez potok CHovojnica       4,
#  n_2023
#  4    20
#  3     8
#  6     2
#  5     2
#  7     1
#  1     1
#  2     1
#  Name: count, dtype: int64)
