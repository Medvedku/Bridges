# %%
import pandas as pd

# Specify the path to your pickle file
pickle_filename = 'df_routes.pkl'

# Load the DataFrame from the pickle file
loaded_df = pd.read_pickle(pickle_filename)

# Now, 'loaded_df' contains the DataFrame that was saved in 'df_routes.pkl'

# %%
loaded_df
# Out:
#     ID_mosta              Okres  \
# 0      M1979            Skalica
# 1      M1833             Senica
# 2      M3446      Bratislava IV
# 3      M7099      Bratislava IV
# 4      M5333       Bratislava V
# ..       ...                ...
# 143    M6688            Gelnica
# 144     M917           Trebišov
# 145    M4021  Vranov nad Topľou
# 146    M1933             Myjava
# 147    M5626          Košice II
#
#                                            Custom_coor     br_lat    br_long  \
# 0                                                 None  48.757287  17.079098
# 1                                                 None  48.634732  16.994971
# 2                                                 None  48.241370  17.034921
# 3    "coordinates": [ [ [ 17.034976, 48.241407 ], [...  48.189060  17.047200
# 4                                                 None  48.125991  17.131041
# ..                                                 ...        ...        ...
# 143                                               None  48.848681  20.932527
# 144                                               None  48.635651  21.717199
# 145                                               None  48.985932  21.700834
# 146                                               None  48.767957  17.562174
# 147                                               None  48.647648  21.203522
#
#      start_lat  start_long    end_lat   end_long  \
# 0    48.729199   17.048036  48.802668  17.162506
# 1    48.586200   16.991340  48.643110  17.006333
# 2    48.205450   17.042718  48.252092  17.033278
# 3    48.179992   17.059569  48.204150  17.043150
# 4    48.101220   17.121390  48.129510  17.130100
# ..         ...         ...        ...        ...
# 143  48.860990   20.905026  48.868673  20.965148
# 144  48.610569   21.780682  48.699365  21.707229
# 145  48.948542   21.710467  49.056025  21.601433
# 146  48.785850   17.563592  48.749000  17.566630
# 147  48.628222   21.165811  48.684930  21.219049
#
#                                    Hexagon_Coordinates  ... Volná_šírka_mosta  \
# 0    [[17.079370628365783, 48.757287384], [17.07923...  ...               9.5
# 1    [[16.995242375727763, 48.634732118], [16.99510...  ...              11.0
# 2    [[17.035190832766478, 48.241369836], [17.03505...  ...             11.22
# 3    [[17.047469491298028, 48.18906], [17.047334745...  ...              14.0
# 4    [[17.1313097892143, 48.125990691], [17.1311752...  ...              10.2
# ..                                                 ...  ...               ...
# 143  [[20.932800287440568, 48.848681353], [20.93266...  ...              11.5
# 144  [[21.717470928681387, 48.635651368], [21.71733...  ...              14.5
# 145  [[21.701107358648898, 48.985932049], [21.70097...  ...               9.5
# 146  [[17.562446945268285, 48.767957281], [17.56231...  ...              12.5
# 147  [[21.203794292349624, 48.647647661], [21.20365...  ...              11.5
#
#     n_2012 n_2022 n_2023 car_time_1  car_time_alt  car_dist_1  car_dist_alt  \
# 0        3      6      6  11.433033     18.948467   12.199233     18.500678
# 1        5      6      6   6.082150     11.664683    6.898138      8.519189
# 2        5      5      5   7.137467      7.748417    5.345132      5.679966
# 3        5      5      5   5.300717      7.567200    3.173784      3.300311
# 4        6      6      6   3.931800      6.252917    3.500090      4.418428
# ..     ...    ...    ...        ...           ...         ...           ...
# 143      4      6      6   8.763633     10.843683    6.087601      6.052665
# 144      3      6      6  18.262417     25.161017   15.347949     15.060859
# 145      5      5      6  21.240017     30.030783   18.880812     18.840312
# 146      3      6      6   9.741033     10.221417    4.300715      6.890124
# 147      3      5      5   6.177517     13.487417    8.372385     10.853289
#
#     time_diff dist_diff
# 0    7.515433  6.301445
# 1    5.582533  1.621051
# 2    0.610950  0.334834
# 3    2.266483  0.126527
# 4    2.321117  0.918338
# ..        ...       ...
# 143  2.080050 -0.034936
# 144  6.898600 -0.287090
# 145  8.790767 -0.040500
# 146  0.480383  2.589409
# 147  7.309900  2.480904
#
# [148 rows x 35 columns]
