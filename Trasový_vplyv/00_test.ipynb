# %%
liste = ["M4240", "M6289", "M1514", "M6702", "M3265", "M5392", "M3386", "M6115", "M5373", "M2717", "M1444", "M3832", "M626", "M5626", "M6681", "M6211", "M121", "M1195", "M1693", "M6062", "M1608", "M2684", "M801", "M3551", "M3592", "M6759", "M2889", "M1211", "M2768", "M6035", "M5676", "M2610", "M3877", "M5624", "M4962", "M2098", "M917", "M5221", "M6917", "M885", "M220", "M6016", "M6288", "M5333", "M3603", "M6916", "M7762", "M5828", "M3082", "M5492", "M1979", "M3516", "M3929", "M7335", "M7368", "M1481", "M562", "M349", "M2846", "M4815", "M6188", "M7186", "M5155", "M1885", "M5833", "M7099", "M7109", "M1902", "M4121", "M2499", "M5243", "M1699", "M4819", "M4123",
         "M5754", "M4684", "M1311", "M419", "M3293", "M2191", "M7332", "M4698", "M634", "M3759", "M618", "M1833", "M4237", "M5001", "M660", "M5316", "M2489", "M6883", "M3959", "M3440", "M3027", "M57", "M3917", "M4653", "M3649", "M5550", "M5574", "M6258", "M2040", "M3182", "M1973", "M1255", "M3882", "M1208", "M5312", "M4021", "M2721", "M3641", "M3446", "M3843", "M6308", "M5125", "M1762", "M3841", "M2877", "M5581", "M3109", "M1945", "M3640", "M6745", "M4087", "M3054", "M6817", "M6419", "M1812", "M7460", "M1296", "M7034", "M1933", "M7568", "M2681", "M1939", "M3276", "M4621", "M6688", "M7118", "M7339", "M5910", "M3069", "M7088", "M3011", "M5686", "M5723", "M6054"]

# %%
liste.sort(key=lambda x: int(x.split("M")[1]))

liste
# Out:
# ['M57',
#  'M121',
#  'M220',
#  'M349',
#  'M419',
#  'M562',
#  'M618',
#  'M626',
#  'M634',
#  'M660',
#  'M801',
#  'M885',
#  'M917',
#  'M1195',
#  'M1208',
#  'M1211',
#  'M1255',
#  'M1296',
#  'M1311',
#  'M1444',
#  'M1481',
#  'M1514',
#  'M1608',
#  'M1693',
#  'M1699',
#  'M1762',
#  'M1812',
#  'M1833',
#  'M1885',
#  'M1902',
#  'M1933',
#  'M1939',
#  'M1945',
#  'M1973',
#  'M1979',
#  'M2040',
#  'M2098',
#  'M2191',
#  'M2489',
#  'M2499',
#  'M2610',
#  'M2681',
#  'M2684',
#  'M2717',
#  'M2721',
#  'M2768',
#  'M2846',
#  'M2877',
#  'M2889',
#  'M3011',
#  'M3027',
#  'M3054',
#  'M3069',
#  'M3082',
#  'M3109',
#  'M3182',
#  'M3265',
#  'M3276',
#  'M3293',
#  'M3386',
#  'M3440',
#  'M3446',
#  'M3516',
#  'M3551',
#  'M3592',
#  'M3603',
#  'M3640',
#  'M3641',
#  'M3649',
#  'M3759',
#  'M3832',
#  'M3841',
#  'M3843',
#  'M3877',
#  'M3882',
#  'M3917',
#  'M3929',
#  'M3959',
#  'M4021',
#  'M4087',
#  'M4121',
#  'M4123',
#  'M4237',
#  'M4240',
# ...
