# %%
import pandas as pd

# # DOMA
# nodes_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
# roads_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Roads_processed.csv"
# bridges_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\df_bridges_data.csv"
# survey_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\surveys\Survey.csv"

# ROBOTA
nodes_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
roads_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Roads_processed.csv"
bridges_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\df_bridges_data.csv"
survey_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\surveys\Survey.csv"

# Load the CSV data into a DataFrame
df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')
df_bridges_all = pd.read_csv(bridges_path, encoding='utf-8', delimiter=',')
df_survey = pd.read_csv(survey_path, encoding='utf-8', delimiter=',')
# Out:
# C:\Users\relia\AppData\Local\Temp\ipykernel_9640\4245361851.py:16: DtypeWarning: Columns (5,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
# C:\Users\relia\AppData\Local\Temp\ipykernel_9640\4245361851.py:17: DtypeWarning: Columns (10,11,12,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')

# %%
import pandas as pd

# Define the columns that should be converted to numeric data types
numeric_columns = ['Normálna_zaťažiteľnosť', 'Výhradná_zaťažiteľnosť_t', 'Výnimočná_zaťažiteľnosť_t',
                   'Počet_otvorov', 'Dĺžka_premostenia', 'Dĺžka_nosnej_konštrukcie_m',
                   'Volná_šírka_mosta', 'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
                   'Plocha_mosta_m2', 'n_2012', 'n_2013', 'n_2014', 'n_2015', 'n_2016',
                   'n_2017', 'n_2018', 'n_2019', 'n_2020', 'n_2021', 'n_2022', 'n_2023']

# Convert the selected columns to numeric data types (integers or floats)
for col in numeric_columns:
    df_bridges_all[col] = pd.to_numeric(df_bridges_all[col], errors='coerce')

# %%
df_bridges_all.columns
# Out:
# Index(['ID_mosta', 'Trieda_PK', 'Číslo_PK', 'Most_DC', 'Názov_mosta', 'ID_DC',
#        'správcovské_číslo', 'Zemepisná_dĺžka', 'Zemepisná_šírka', 'Výška',
#        'Druh_konštrukcie', 'Material', 'Normálna_zaťažiteľnosť',
#        'Výhradná_zaťažiteľnosť_t', 'Výnimočná_zaťažiteľnosť_t',
#        'Spôsob_stanovenia', 'Predmet_premostenia', 'Rok_postavenia',
#        'Zaťažovacia_trieda_STN', 'Počet_otvorov', 'Dĺžka_premostenia',
#        'Dĺžka_nosnej_konštrukcie_m', 'Volná_šírka_mosta',
#        'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
#        'Plocha_mosta_m2', 'Vlastník_úseku', 'Správca_úseku', 'Okres',
#        'Smer_úseku', 'Typ_úseku', 'Počiatočný_uzol', 'Koncový_uzol', 'úsek_ID',
#        'úsekové_staničenie_začiatku_DC_m',
#        'Kilometrovníkové_staničenie_začiatku_DC_km',
#        'Kumulatívne_staničenie_začiatku_DC_km', 'Poradie', 'Kraj', 'n_2012',
#        'n_2013', 'n_2014', 'n_2015', 'n_2016', 'n_2017', 'n_2018', 'n_2019',
#        'n_2020', 'n_2021', 'n_2022', 'n_2023'],
#       dtype='object')

# %%
list(df_bridges_all["Správca_úseku"].value_counts().keys())
# Out:
# ['SSC - IVSC ZA',
#  'SSC - IVSC KE',
#  'SSC - IVSC BB',
#  'BBRSC-JUH',
#  'BBRSC-STRED',
#  'BBRSC-SEVER',
#  'SSC - IVSC BA',
#  'SUC PSK - HE',
#  'SC TN SK - TN',
#  'SUC PSK - PO',
#  'SC TN SK - PD',
#  'SUC TTSK - TT',
#  'SUC PSK - PP',
#  'SUC PSK - BJ',
#  'SC TN SK - PB',
#  'SC ŽSK - HPOV',
#  'SC KSK - KS',
#  'SC ŽSK - ORA',
#  'SC ŽSK - LIP',
#  'SUC PSK - SK',
#  'SC KSK - SNV',
#  'RSUC NR - LV',
#  'SUC PSK - SL',
#  'SC ŽSK - KYS',
#  'RSUC NR - NR',
#  'SC KSK - MI',
#  'SC BSK',
#  'SC ŽSK - TUR',
#  'SUC TTSK - SE',
#  'NDS - SSUR ZV',
#  'SC KSK - TV',
#  'RSUC NR - NZ',
#  'NDS - SSUD PB',
#  'VPO',
#  'SC KSK - RV',
#  'SUC PSK - VT',
#  'NDS - SSUD LM',
#  'SUC TTSK - DS',
#  'RSUC NR - TO',
#  'RSUC NR - KN',
#  'NDS - SSUR KE',
#  'NDS - SSUD TN',
#  'NDS - SSUD BE',
#  'NDS - SSUR CA',
#  'NDS - SSUD BA',
#  'MAG-BA',
#  'NDS - SSUR NB',
#  'NDS - SSUD PO',
#  'NDS - SSUR GA',
#  'NDS - SSUD MENG',
#  'NDS - SSUD MA',
#  'NDS - SSUD TT',
#  'NDS - SSUD MT',
#  'MAG-KE',
#  'CU',
#  'ZA-Invest',
#  'NO-HR',
#  'HE',
#  'BJ',
#  'SB-LI',
#  'ZI',
#  'LM-DD',
#  'PN',
#  'VK-NV',
#  'BR-PL',
#  'BB']

# %%
# Filter bridges in the Nitra region with Trieda_PK as "cesta I. triedy" or "cesta II. triedy"
bridges_KSK = df_bridges_all[
    ((df_bridges_all["Správca_úseku"] == 'SC KSK - KS') |
     (df_bridges_all["Správca_úseku"] == 'SC KSK - SNV') |
     (df_bridges_all["Správca_úseku"] == 'SC KSK - MI') |
     (df_bridges_all["Správca_úseku"] == 'SC KSK - TV') |
     (df_bridges_all["Správca_úseku"] == 'SC KSK - RV')) &
    (df_bridges_all["Predmet_premostenia"] != 'Železnica') &
    (df_bridges_all["Material"] == 'prefabrikovaný predpätý betón')
]

# Display the filtered DataFrame
bridges_KSK.shape
# Out:
# (134, 51)

# %%
sorted_bridges = bridges_KSK.sort_values(
    by='Dĺžka_premostenia', ascending=False)

sorted_bridges[["ID_mosta", 'Názov_mosta', 'Zemepisná_šírka',
                'Zemepisná_dĺžka', "Dĺžka_premostenia", "Predmet_premostenia","Material", "n_2023"]].head(20)
# Out:
#      ID_mosta                                        Názov_mosta  \
# 2647    M2774              Most cez rieku Ondava pri obci Sírnik
# 2695    M4732     Most cez rieku Uh pred obcou Pavlovce nad Uhom
# 2653    M1510           Most cez rieku Laborec pred obcou Vojany
# 2377    M2432  Most - nadcestie cez cestu II/533 v meste Spiš...
# 6471    M5734                 Most cez rieku Uh v obci Lekárovce
# 6406    M7266                            Most na priehrade Ružín
# 6407    M3340                 Most cez Hornád v obci Malá Lodina
# 6499    M2472              Most cez rieku Topľu za obcou Božčice
# 6389    M1634  Most cez rieku Hornád v obci Družstevná pri Ho...
# 4044     M158               Most cez Laborec za obcou Krivošťany
# 5012    M6874            Most cez rieku Torysu pri obci Vajkovce
# 3994    M3617            Most cez rieku Torysa pred obcou Byster
# 2579    M3739   Most cez potok Belá za obcou Košická Belá (D258)
# 2652    M1683         Most cez inundačný kanál pred obcou Vojany
# 4041    M1687          Most cez nápustný kanál pred obcou Zbudza
# 4980    M4047                Most cez rieku Torysu v obci Ploské
# 4085    M3283            Most cez rieku Torysu v obci Beniakovce
# 6562    M1770  555003- 001 Most cez rieku Laborec za obcou St...
# 3005    M1608                  Most cez rieku Laborec v km 0,504
# 6475    M1700         Most cez Jenkovský kanál za obcou Jenkovce
#
#       Zemepisná_šírka  Zemepisná_dĺžka  Dĺžka_premostenia Predmet_premostenia  \
# 2647        48.508774        21.810388             198.97           Vodný tok
# 2695        48.628430        22.044846             144.78           Vodný tok
# 2653        48.569904        21.981360             126.54           Vodný tok
# 2377        48.950959        20.567513              93.94  Cestná komunikácia
# 6471        48.604701        22.157007              93.80           Vodný tok
# 6406        48.861167        21.098033              87.86         Vodná nádrž
# 6407        48.876526        21.132802              78.50           Vodný tok
# 6499        48.764256        21.735034              74.00           Vodný tok
# 6389        48.800273        21.244517              70.84           Vodný tok
# 4044        48.877372        21.850616              67.00           Vodný tok
# 5012        48.781621        21.314422              66.30           Vodný tok
# 3994        48.705902        21.339134              61.21           Vodný tok
# 2579        48.810528        21.096159              58.13           Vodný tok
# 2652        48.570076        21.973822              57.00    Záplavové územie
# 4041        48.793906        21.900720              56.50               Kanál
# 4980        48.813281        21.315929              56.40           Vodný tok
# 4085        48.769908        21.319136              56.20           Vodný tok
# 6562        48.618590        21.980320              55.88           Vodný tok
# 3005        48.760147        21.919973              53.95           Vodný tok
# 6475        48.661799        22.207429              52.26               Kanál
#
#                            Material  n_2023
# 2647  prefabrikovaný predpätý betón       7
# 2695  prefabrikovaný predpätý betón       4
# 2653  prefabrikovaný predpätý betón       6
# 2377  prefabrikovaný predpätý betón       4
# 6471  prefabrikovaný predpätý betón       6
# 6406  prefabrikovaný predpätý betón       6
# 6407  prefabrikovaný predpätý betón       5
# 6499  prefabrikovaný predpätý betón       3
# 6389  prefabrikovaný predpätý betón       5
# 4044  prefabrikovaný predpätý betón       1
# 5012  prefabrikovaný predpätý betón       6
# 3994  prefabrikovaný predpätý betón       4
# 2579  prefabrikovaný predpätý betón       5
# 2652  prefabrikovaný predpätý betón       6
# 4041  prefabrikovaný predpätý betón       6
# 4980  prefabrikovaný predpätý betón       6
# 4085  prefabrikovaný predpätý betón       4
# 6562  prefabrikovaný predpätý betón       6
# 3005  prefabrikovaný predpätý betón       6
# 6475  prefabrikovaný predpätý betón       4

# %%
bridges_KSK.columns
# Out:
# Index(['ID_mosta', 'Trieda_PK', 'Číslo_PK', 'Most_DC', 'Názov_mosta', 'ID_DC',
#        'správcovské_číslo', 'Zemepisná_dĺžka', 'Zemepisná_šírka', 'Výška',
#        'Druh_konštrukcie', 'Material', 'Normálna_zaťažiteľnosť',
#        'Výhradná_zaťažiteľnosť_t', 'Výnimočná_zaťažiteľnosť_t',
#        'Spôsob_stanovenia', 'Predmet_premostenia', 'Rok_postavenia',
#        'Zaťažovacia_trieda_STN', 'Počet_otvorov', 'Dĺžka_premostenia',
#        'Dĺžka_nosnej_konštrukcie_m', 'Volná_šírka_mosta',
#        'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
#        'Plocha_mosta_m2', 'Vlastník_úseku', 'Správca_úseku', 'Okres',
#        'Smer_úseku', 'Typ_úseku', 'Počiatočný_uzol', 'Koncový_uzol', 'úsek_ID',
#        'úsekové_staničenie_začiatku_DC_m',
#        'Kilometrovníkové_staničenie_začiatku_DC_km',
#        'Kumulatívne_staničenie_začiatku_DC_km', 'Poradie', 'Kraj', 'n_2012',
#        'n_2013', 'n_2014', 'n_2015', 'n_2016', 'n_2017', 'n_2018', 'n_2019',
#        'n_2020', 'n_2021', 'n_2022', 'n_2023'],
#       dtype='object')
