# %%
import pandas as pd

## DOMA
# Define the file path
nodes_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
roads_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Roads_processed.csv"
bridges_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\df_bridges_2024_all.csv"
bridges_selected_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_selected.csv"
survey_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\surveys\Survey.csv"

# # Práca
# # Define the file path
# nodes_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
# roads_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Roads_processed.csv"
# bridges_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Bridges_processed.csv"
# bridges_selected_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\Bridges_selected.csv"
# survey_path = r"C:\Users\relia\Documents\GitHub\Bridges\Data\surveys\Survey.csv"

# Load the CSV data into a DataFrame
df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')
df_bridges_all = pd.read_csv(bridges_path, encoding='utf-8', delimiter=',')
df_bridges_sel = pd.read_csv(
    bridges_selected_path, encoding='utf-8', delimiter=',')
df_survey = pd.read_csv(survey_path, encoding='utf-8', delimiter=',')
# Out:
# C:\Users\Doktor\AppData\Local\Temp\ipykernel_272\694944326.py:20: DtypeWarning: Columns (5,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
# C:\Users\Doktor\AppData\Local\Temp\ipykernel_272\694944326.py:21: DtypeWarning: Columns (10,11,12,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')

# %%
df_bridges_all['Dĺžka_premostenia'] = pd.to_numeric(
    df_bridges_all['Dĺžka_premostenia'], errors='coerce')

df_bridges_all.columns
# Out:
# Index(['ID_mosta', 'Trieda_PK', 'Číslo_PK', 'Názov_mosta', 'správcovské_číslo',
#        'Zemepisná_šírka', 'Zemepisná_dĺžka', 'Výška', 'Druh_konštrukcie',
#        'Material', 'Normálna_zaťažiteľnosť', 'Výhradná_zaťažiteľnosť_t',
#        'Výnimočná_zaťažiteľnosť_t', 'Spôsob_stanovenia', 'Predmet_premostenia',
#        'Rok_postavenia', 'Zaťažovacia_trieda_STN', 'Počet_otvorov',
#        'Dĺžka_premostenia', 'Dĺžka_nosnej_konštrukcie_m', 'Volná_šírka_mosta',
#        'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
#        'Plocha_mosta_m2', 'Vlastník_úseku', 'Správca_úseku', 'Okres',
#        'Počiatočný_uzol', 'Koncový_uzol', 'úsek_ID', 'Kraj', 'n_2012',
#        'n_2013', 'n_2014', 'n_2015', 'n_2016', 'n_2017', 'n_2018', 'n_2019',
#        'n_2020', 'n_2021', 'n_2022', 'n_2023', 'n_2024'],
#       dtype='object')

# %%
filtered_bridges = df_bridges_all.copy()

# Filter bridges in the Nitra region with Trieda_PK as "cesta I. triedy" or "cesta II. triedy"
filtered_bridges = df_bridges_all[
    ((df_bridges_all['Správca_úseku'] == 'RSUC NR - LV') |
     (df_bridges_all['Správca_úseku'] == 'RSUC NR - NR') |
     (df_bridges_all['Správca_úseku'] == 'RSUC NR - NZ') |
     (df_bridges_all['Správca_úseku'] == 'RSUC NR - TO') |
     (df_bridges_all['Správca_úseku'] == 'RSUC NR - KN')
     )
]

# Reindex the DataFrame
filtered_bridges.reset_index(drop=True, inplace=True)

filtered_bridges = filtered_bridges[filtered_bridges["n_2024"] != 0]

# Display the filtered DataFrame
filtered_bridges.shape
# Out:
# (531, 44)

# %%
sala_bridges = filtered_bridges[
    (filtered_bridges['Okres'] == 'Šaľa')]
sala_bridges[["ID_mosta", "Názov_mosta", "n_2024", "Dĺžka_premostenia", "Material"]]
# Out:
#     ID_mosta                                        Názov_mosta  n_2024  \
# 48      M765              Most cez Dudváh za obcou Dolné Saliby       4
# 53     M4637     Most cez odvodňovací kanál - Trnovec nad Váhom       4
# 54     M3430  Most na ceste II/562 cez Dlhý kanál v k.ú. Trn...       4
# 55     M7310  Most cez odvodňovací kanál pred obcou Trnovec ...       3
# 177    M3284                 Most v Hornej Kráľovej - cez potok       5
# 219     M270   Most cez odvodňovací kanál pred obcou Palárikovo       4
# 324     M418               Most cez Šalský odpad v obci Žihárec       4
# 325    M4043          Most cez odvodňovací kanál v obci Žihárec       4
# 326    M5219  Most cez odvodňovací kanál medzi obcami Žiháre...       6
# 327    M1699       Most cez odvodňovací kanál Veča - Duslo Šaľa       6
# 328    M2705                      Most v kat. Močenok cez potok       4
# 333    M1386                            Most v k.ú. Horný Jatov       4
# 479    M7700     Most cez odvodňovací kanál pred obcou Diakovce       3
# 488      M93                                Most v obci Močenok       4
# 489    M5299                                 Most v obci Hájske       4
# 508    M3905             Most medzi hrádzami Váhu v obci Vlčany       6
#
#      Dĺžka_premostenia                       Material
# 48                9.10        monolitický železobetón
# 53                3.50        monolitický železobetón
# 54               15.80     prefabrikovaný železobetón
# 55                3.12             oceľ -  plnostenná
# 177               3.15        monolitický železobetón
# 219               6.20        monolitický železobetón
# 324               2.95             oceľ -  plnostenná
# 325               2.05                          tehla
# 326               4.10        monolitický železobetón
# 327               2.05        monolitický železobetón
# 328              10.82  prefabrikovaný predpätý betón
# 333               4.50        monolitický železobetón
# 479               6.00        monolitický železobetón
# 488               3.00        monolitický železobetón
# 489               2.50        monolitický železobetón
# 508               2.30             oceľ -  plnostenná
