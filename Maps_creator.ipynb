# %%
import pandas as pd

# Specify the path to your Excel file
excel_file_path = 'Nitra/Tabulka.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(excel_file_path)

# Now, 'df' contains your data as a DataFrame, and you can work with it.

# %%
df.columns
# Out:
# Index(['ID mosta', 'Názov mosta', 'STS - slovne', 'STS', 'Okres', 'Latitude',
#        'Longitude', 'Material', 'Dĺžka premostenia / m', 'Rok postavenia'],
#       dtype='object')

# %%
import folium


# Create a map centered on Slovakia (you can adjust the coordinates and zoom level)
m = folium.Map(location=[48.63, 21.3], zoom_start=9, tiles='Stamen Toner')

# Define the custom marker icons for each condition
markers_palette = {
    1: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_1.svg',  # Bezchybný
    2: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_2.svg',  # Veľmi dobrý
    3: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_3.svg',  # Dobrý
    4: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_4.svg',  # Uspokojivý
    5: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_5.svg',  # Zlý
    6: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_6.svg',  # Veľmi zlý
    7: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_7.svg',  # Havarijný
    0: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_0.svg',  # Nezistený
}

# Iterate through your DataFrame and add markers for each bridge with custom icons and HTML popups
for index, row in df.iterrows():
    condition = row['STS']  # Get the condition value for the bridge
    marker_icon_url = markers_palette[condition]  # Get the corresponding marker URL
    
    # Create an HTML popup with custom content including Montserrat font
    popup_html = f"""
    <h4>Údaje o moste: {row['ID mosta']}</h4>
    <p>
    Názov: {row['Názov mosta']} <br>
    Okres: {row['Okres']} <br>
    STS {row['STS']} - {row['STS - slovne']}<br>
    </p>
    """
    
    custom_marker_icon = folium.CustomIcon(
        icon_image=marker_icon_url,
        icon_size=(50, 50),  # Adjust the size as needed
        icon_anchor=(25, 50),  # Adjust the anchor point as needed
    )
    
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_html, max_width=300),  # Use the HTML popup
        icon=custom_marker_icon,  # Use the custom icon
    ).add_to(m)

# Display the map
#m#.save('bridges_map_NR_STS6.html')

# %%
import folium

# Define a dictionary to map bridge names to image URLs
bridge_images = {
    "M57": "https://drive.google.com/uc?id=1a-i_3_XwL2Sq0aXc8XZY_Fy67FSsoT_K",
    "M145": "https://drive.google.com/uc?id=1eUl_6KiHLSy5VcACVcv1XY9wIGa_yKOc",
    "M741": "https://drive.google.com/uc?id=1IbQ7wEPTlL2vnG0dDN8BTwSGOvAsDSCt",
    "M1033": "https://drive.google.com/uc?id=1VDaofEFHR22EUmKk284Prr4uL5tC0XQH",
    "M1524": "https://drive.google.com/uc?id=18Scuw5Wi4pEeOLqYn51mTaasRz4dAHhn",
    "M1769": "https://drive.google.com/uc?id=1cemfPHIsWP8JzJvDB7esOSIfoM594uAo",
    "M1878": "https://drive.google.com/uc?id=1vSZe_ejE1lewP3WD5PAvD6peN4Z8kImY",
    "M2026": "https://drive.google.com/uc?id=1xhafNf4I3vukQxONj0yYyPwcNOw8U0X-",
    "M2093": "https://drive.google.com/uc?id=1ARMetVtlqcwb6cncQQ5eb9R_0e0lugSj",
    "M2459": "https://drive.google.com/uc?id=17jlnI9J9MadtyWhwoP317gNHu2uBSFY_",
    "M4264": "https://drive.google.com/uc?id=1RYyeo0ZGDbVrswnKU8bXleT1NYyXsA1W",
    "M4328": "https://drive.google.com/uc?id=1BQQ5NC53NvwPXtAX5f3RpEM-xcu1us9b",
    "M5728": "https://drive.google.com/uc?id=119QLx_vw5mtCYWHrnqHEv7qDFYg1rf0g",
    "M6007": "https://drive.google.com/uc?id=1pc3-29YcR34RpDEpjvWv-ZT3bSgwNm0N",
    "M6174": "https://drive.google.com/uc?id=1Hl60j4AN4L6ukrxsY2enLuyA1wnfK8z8",
    "M6734": "https://drive.google.com/uc?id=1Hv1bDP0bHOCrOYgv8vAvM-5opaAs_cyB",
    "M6745": "https://drive.google.com/uc?id=1YFIkTeuBidR093Vnyv6NzNY3tqSSd53b",
    "M7083": "https://drive.google.com/uc?id=1hX1vSCngUVwEC2-8ph5yUiIoSIdcoMPm",
    "M7383": "https://drive.google.com/uc?id=1xFKQPMQXemKNefRzxrCLaSsUW24e6BSx"
    # Add more bridges and their image URLs as needed
}

# Define a dictionary to map bridge names to image URLs
bridge_urls = {
    "M57":   "https://drive.google.com/drive/folders/1DqAvRIhF0B2qBq9EnzHD_8sp_V9ssy5n?usp=drive_link",
    "M145":  "https://drive.google.com/drive/folders/1C4oLXbyDtxAFCaEVvwLdGV28uEjazZHZ?usp=drive_link",
    "M741":  "https://drive.google.com/drive/folders/1ABSXcXh95C5TeCbSzW_OdwAE9hIXOXf8?usp=drive_link",
    "M1033": "https://drive.google.com/drive/folders/1Con396o_i3OKR5TChAnzH1TNOV_OhE-G?usp=drive_link",
    "M1524": "https://drive.google.com/drive/folders/1HEEvl75__AjPniCqPipg0qasEo6gk3Uk?usp=drive_link",
    "M1769": "https://drive.google.com/drive/folders/1GGoQLRjDQ_nA3-H_2dQwNVuGpzSaa9HN?usp=drive_link",
    "M1878": "https://drive.google.com/drive/folders/1Ezl8y0eSMd8-yPql89Cd1uDPc5ouBoG1?usp=drive_link",
    "M2026": "https://drive.google.com/drive/folders/1BAZZ90iHinj-KqnOJ5430ZRuhyTbPMxk?usp=drive_link",
    "M2093": "https://drive.google.com/drive/folders/1EWJj61WdjmS-qtIt8ExWi7zzz1LETC_M?usp=drive_link",
    "M2459": "https://drive.google.com/drive/folders/1GWP-n_lfkUcmNKA8-MgxU-Vyw0Jqm5a6?usp=drive_link",
    "M4264": "https://drive.google.com/drive/folders/1HhjXER8fvky6mw-sMPv3kDucT-jYShxd?usp=drive_link",
    "M4328": "https://drive.google.com/drive/folders/1FjcxmRi0J2F51BMhd86mu0FzqFpk_QLt?usp=drive_link",
    "M5728": "https://drive.google.com/drive/folders/1r2FzdnhYryKAnWMIRCrPJkRxati8E8Ol?usp=drive_link",
    "M6007": "https://drive.google.com/drive/folders/17fGMU2XuAZ6vrQ9EmslR3h4Kq7AzXYx5?usp=drive_link",
    "M6174": "https://drive.google.com/drive/folders/19sDgVfCPdMv7qOw2c-4p0JiTSQqaK2gf?usp=drive_link",
    "M6734": "https://drive.google.com/drive/folders/19sDbs3nCZDFDtJmuLeqMY52WlKV2vjSi?usp=drive_link",
    "M6745": "https://drive.google.com/drive/folders/1CU7zHt8tMe-vPIFS1bEsvuHEp5Aqqjgy?usp=drive_link",
    "M7083": "https://drive.google.com/drive/folders/1BmiERGF6LbwGQCJkGNmBp_sKQUqY_r6E?usp=drive_link",
    "M7383": "https://drive.google.com/drive/folders/1DWDBx4pEhqIA3Cl0G2Q80MYn7DgOvQ2q?usp=drive_link"
    # Add more bridges and their image URLs as needed
}

# Create a map centered on Slovakia (you can adjust the coordinates and zoom level)
m = folium.Map(location=[48.2, 18.3], zoom_start=10, tiles='Stamen Toner')

markers_palette = {
    1: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_1.svg',  # Bezchybný
    2: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_2.svg',  # Veľmi dobrý
    3: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_3.svg',  # Dobrý
    4: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_4.svg',  # Uspokojivý
    5: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_5.svg',  # Zlý
    6: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_6.svg',  # Veľmi zlý
    7: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_7.svg',  # Havarijný
    0: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_0.svg',  # Nezistený
}

# Iterate through your DataFrame and add markers for each bridge with custom icons and HTML popups
for index, row in df.iterrows():
    condition = row['STS']
    marker_icon_url = markers_palette[condition]
    
    # Get the bridge name
    bridge_name = row['ID mosta']
    
    # Get the image URL for the bridge based on its name
    if bridge_name in bridge_images:
        image_url = bridge_images[bridge_name]
    else:
        image_url = 'URL_for_default_image_if_bridge_name_not_found'


    # Get the URL for the bridge based on its name
    if bridge_name in bridge_urls:
        bridge_url = bridge_urls[bridge_name]
    else:
        bridge_url = 'URL_for_default_bridge_if_bridge_name_not_found'
    

    # Create an HTML popup with tabular content
    popup_html = f"""
    <h4>ID: {bridge_name}</h4>
    <table>
        <tr>
            <td><u>Názov:</u></td>
            <td>&nbsp; {row['Názov mosta']}</td>
        </tr>
        <tr>
            <td><u>Rok postavenia:</u></td>
            <td>&nbsp; {row['Rok postavenia']} (pred {2023 - row['Rok postavenia']} rokmi)</td>
        </tr>
        <tr>
            <td><u>Okres:</u></td>
            <td>&nbsp; {row['Okres']}</td>
        </tr>
        <tr>
            <td><u>Dĺžka:</u></td>
            <td>&nbsp; {row['Dĺžka premostenia / m']} m</td>
        </tr>
        <tr>
            <td><u>Materiál:</u></td>
            <td>&nbsp; {row['Material']}</td>
        </tr>
        <tr>
            <td><u>STS</u></td>
            <td>&nbsp; {row['STS - slovne']} - {row['STS']}</td>
        </tr>
    </table>
    <a href="{bridge_url}" target="_blank">  <!-- Add the link around the image -->
        <img src="{image_url}" alt="{bridge_name}" width="300px">
    </a>
    """


    custom_marker_icon = folium.CustomIcon(
        icon_image=marker_icon_url,
        icon_size=(50, 50),  # Adjust the size as needed
        icon_anchor=(25, 50),  # Adjust the anchor point as needed
    )
    
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_html, max_width=300),
        icon=custom_marker_icon,
    ).add_to(m)

# Display the map
m#.save('bridges_map_NR_STS6.html')

# %%
import pandas as pd

# Specify the path to your Excel file
excel_file_path = 'data_full.csv'

# Read the Excel file into a DataFrame
df = pd.read_csv(excel_file_path)

# Now, 'df' contains your data as a DataFrame, and you can work with it.

# %%
df.columns
# Out:
# Index(['ID mosta', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023', 'Okres', 'Longitude',
#        'Latitude', 'Material', 'Názov mosta', 'Dĺžka premostenia',
#        'Rok postavenia', 'Volná šírka mosta', 'Normána zaťažiteľnost',
#        'Trieda PK', 'Druh konštrukcie', 'Kraj', 'n_2012', 'n_2013', 'n_2014',
#        'n_2015', 'n_2016', 'n_2017', 'n_2018', 'n_2019', 'n_2020', 'n_2021',
#        'n_2022', 'n_2023'],
#       dtype='object')

# %%
df['Trieda PK'].value_counts()
# Out:
# Trieda PK
# cesta III. triedy                      3973
# cesta I. triedy                        1928
# cesta II. triedy                       1479
# diaľnica                                900
# Nezistený                               193
# miestna neurčená                         24
# účelová cesta (UC)                        3
# II. trieda - miestna zberná (MZ)          1
# III. trieda - miestna obslužná (MO)       1
# Name: count, dtype: int64

# %%
import folium

# Convert the "Dĺžka premostenia" column to numeric (assuming it's in meters)
df["Dĺžka premostenia"] = pd.to_numeric(df["Dĺžka premostenia"], errors='coerce')


target_region = 'Prešov'
target_region = 'Košice'  # Specify the target region

# Filter the DataFrame for bridges with valid coordinates in the Košice region
filtered_df = df[
    (df["Longitude"] != "Nezistený") & 
    (df["Latitude"] != "Nezistený") & 
    (df["Kraj"] == target_region) &
    (df["Material"] == "prefabrikovaný predpätý betón") &
    ((df['n_2023'] == 6) | (df['n_2023'] == 5) | (df['n_2023'] == 7)) &
    ( (df['Trieda PK'] == "cesta II. triedy") | (df['Trieda PK'] == "cesta III. triedy ") )
]

# Count the number of displayed bridges
num_displayed_bridges = len(filtered_df)
print(f"Number of displayed bridges: {num_displayed_bridges}")

# Create a map centered on Slovakia (you can adjust the coordinates and zoom level)
m = folium.Map(location=[49.11, 21.08], zoom_start=9)

# Define the custom marker icons for each condition
markers_palette = {
    1: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_1.svg',  # Bezchybný
    2: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_2.svg',  # Veľmi dobrý
    3: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_3.svg',  # Dobrý
    4: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_4.svg',  # Uspokojivý
    5: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_5.svg',  # Zlý
    6: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_6.svg',  # Veľmi zlý
    7: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_7.svg',  # Havarijný
    0: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_0.svg',  # Nezistený
}

# Iterate through your DataFrame and add markers for each bridge with custom icons and HTML popups
for index, row in filtered_df.iterrows():
    condition = row['n_2023']  # Get the condition value for the bridge
    marker_icon_url = markers_palette[condition]  # Get the corresponding marker URL
    

    # Create an HTML popup with tabular content
    popup_html = f"""
    <h4>ID: {row['ID mosta']}</h4>
    <table>
        <tr>
            <td><u>Názov:</u>&nbsp; </td>
            <td>{row['Názov mosta']}</td>
        </tr>
        <tr>
            <td><u>Rok:</u>&nbsp; </td>
            <td>{int(float(row['Rok postavenia']))} (pred {int(2023 - float(row['Rok postavenia']))} rokmi)</td>
        </tr>
        <tr>
            <td><u>Okres:</u>&nbsp; </td>
            <td>{row['Okres']}</td>
        </tr>
        <tr>
            <td><u>Dĺžka:</u>&nbsp; </td>
            <td>{row['Dĺžka premostenia']} m</td>
        </tr>
        <tr>
            <td><u>Materiál:</u>&nbsp; </td>
            <td>{row['Material']}</td>
        </tr>
        <tr>
            <td><u>STS</u>&nbsp; </td>
            <td>{row['2023']} - {row['n_2023']}</td>
        </tr>
    </table>
    """


    custom_marker_icon = folium.CustomIcon(
        icon_image=marker_icon_url,
        icon_size=(50, 50),  # Adjust the size as needed
        icon_anchor=(25, 50),  # Adjust the anchor point as needed
    )
    
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_html, max_width=300),  # Use the HTML popup
        icon=custom_marker_icon,  # Use the custom icon
    ).add_to(m)

# Display the map
m.save(f'bridges_map_{target_region}.html')
# Out:
# Number of displayed bridges: 22

# %%
# filtered_df["Material"].value_counts()
filtered_df.columns
# Out:
# Index(['ID mosta', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023', 'Okres', 'Longitude',
#        'Latitude', 'Material', 'Názov mosta', 'Dĺžka premostenia',
#        'Rok postavenia', 'Volná šírka mosta', 'Normána zaťažiteľnost',
#        'Trieda PK', 'Druh konštrukcie', 'Kraj', 'n_2012', 'n_2013', 'n_2014',
#        'n_2015', 'n_2016', 'n_2017', 'n_2018', 'n_2019', 'n_2020', 'n_2021',
#        'n_2022', 'n_2023'],
#       dtype='object')

# %%
import folium

# Convert the "Dĺžka premostenia" column to numeric (assuming it's in meters)
df["Dĺžka premostenia"] = pd.to_numeric(df["Dĺžka premostenia"], errors='coerce')


target_region = 'Košice'  # Specify the target region
target_region = 'Prešov'

# Filter the DataFrame for bridges with valid coordinates in the Košice region
filtered_df = df[
    (df["Longitude"] != "Nezistený") & 
    (df["Latitude"] != "Nezistený") & 
    (df["Kraj"] == target_region) &
    (df["Material"] == "prefabrikovaný predpätý betón") &
    ((df['n_2023'] == 6) | (df['n_2023'] == 5) | (df['n_2023'] == 7)) &
    ( (df['Trieda PK'] == "cesta II. triedy") | (df['Trieda PK'] == "cesta III. triedy ") )
]

# Count the number of displayed bridges
num_displayed_bridges = len(filtered_df)
print(f"Number of displayed bridges: {num_displayed_bridges}")

filtered_df = filtered_df[['ID mosta', 'Názov mosta', "Okres", "2023", "Dĺžka premostenia", "Material", "Rok postavenia", 'Longitude',
       'Latitude']]

# Change "Rok postavenia" column to integers
filtered_df["Rok postavenia"] = filtered_df["Rok postavenia"].astype(float)
# Change "Rok postavenia" column to integers
filtered_df["Rok postavenia"] = filtered_df["Rok postavenia"].astype(int)

# Create a new column with links to Google Maps
filtered_df["Google Maps Link"] = filtered_df.apply(lambda row: f"https://www.google.com/maps?q={row['Latitude']},{row['Longitude']}", axis=1)

filtered_df = filtered_df.drop(columns=['Longitude', 'Latitude', "Material"])


# Assuming you want to rename multiple columns
column_mapping = {
    'Rok postavenia': 'Rok',
    'Dĺžka premostenia': 'Dĺžka',
    '2023': 'STS'
}

filtered_df = filtered_df.rename(columns=column_mapping)

# Specify the path where you want to save the XLSX file
output_file_path = f'filtered_bridges_{target_region}.xlsx'

# Save the DataFrame to an XLSX file
filtered_df.to_excel(output_file_path, index=False)
# Out:
# Number of displayed bridges: 40

# %%
filtered_df
# Out:
#      ID mosta                                        Názov mosta       Okres  \
# 596     M1273  16-293 Most cez cestu a potok za obcou Jablono...     Rožňava
# 1305    M2619  67-015 Most cez Súľovský potok v obci Gemerská...     Rožňava
# 1308    M3592   67_018 most cez rieku Slaná pred obcou Henckovce     Rožňava
# 1801    M5379        79_011 Most cez potok pred obcou Parchovany    Trebišov
# 1806    M7802  79_020 Most cez širokorozchodnú vlečku, k.ú. T...    Trebišov
# ...       ...                                                ...         ...
# 6658    M4957             Most cez potok Chlmec pred obcou Hrčeľ    Trebišov
# 6666    M3841                Most cez kanál za obcou Veľký Horeš    Trebišov
# 6670     M338    Most cez kanál pred križovatkou s cestou 553024    Trebišov
# 6679     M917           553047- 001A Most nad železničnou traťou    Trebišov
# 6718    M1770  555003- 001 Most cez rieku Laborec za obcou St...  Michalovce
#
#             STS   Dĺžka   Rok  \
# ...

# %%
# Specify the path where you want to save the XLSX file
output_file_path = 'filtered_bridges_Presov.xlsx'

# Save the DataFrame to an XLSX file
filtered_df.to_excel(output_file_path, index=False)

# %%
import folium

# Convert the "Dĺžka premostenia" column to numeric (assuming it's in meters)
df["Dĺžka premostenia"] = pd.to_numeric(df["Dĺžka premostenia"], errors='coerce')



# Filter the DataFrame for bridges with valid coordinates in the Košice region
filtered_df = df[
    (df["Longitude"] != "Nezistený") & 
    (df["Latitude"] != "Nezistený") & 
    ((df['n_2023'] == 7))
]

# Count the number of displayed bridges
num_displayed_bridges = len(filtered_df)
print(f"Number of displayed bridges: {num_displayed_bridges}")

# Create a map centered on Slovakia (you can adjust the coordinates and zoom level)
m = folium.Map(location=[48.724, 19.561], zoom_start=8)

# Define the custom marker icons for each condition
markers_palette = {
    1: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_1.svg',  # Bezchybný
    2: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_2.svg',  # Veľmi dobrý
    3: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_3.svg',  # Dobrý
    4: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_4.svg',  # Uspokojivý
    5: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_5.svg',  # Zlý
    6: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_6.svg',  # Veľmi zlý
    7: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_7.svg',  # Havarijný
    0: 'https://raw.githubusercontent.com/Medvedku/Assets/9d3208870f50e96e7907ec8394da05bc765a3943/markers/nmark_0.svg',  # Nezistený
}

# Iterate through your DataFrame and add markers for each bridge with custom icons and HTML popups
for index, row in filtered_df.iterrows():
    condition = row['n_2023']  # Get the condition value for the bridge
    marker_icon_url = markers_palette[condition]  # Get the corresponding marker URL
    

    # Create an HTML popup with tabular content
    popup_html = f"""
    <h4>ID: {row['ID mosta']}</h4>
    <table>
        <tr>
            <td><u>Názov:</u>&nbsp; </td>
            <td>{row['Názov mosta']}</td>
        </tr>
        <tr>
            <td><u>Rok:</u>&nbsp; </td>
            <td>{int(float(row['Rok postavenia']))} (pred {int(2023 - float(row['Rok postavenia']))} rokmi)</td>
        </tr>
        <tr>
            <td><u>Okres:</u>&nbsp; </td>
            <td>{row['Okres']}</td>
        </tr>
        <tr>
            <td><u>Dĺžka:</u>&nbsp; </td>
            <td>{row['Dĺžka premostenia']} m</td>
        </tr>
        <tr>
            <td><u>Materiál:</u>&nbsp; </td>
            <td>{row['Material']}</td>
        </tr>
        <tr>
            <td><u>STS</u>&nbsp; </td>
            <td>{row['2023']} - {row['n_2023']}</td>
        </tr>
    </table>
    """


    custom_marker_icon = folium.CustomIcon(
        icon_image=marker_icon_url,
        icon_size=(50, 50),  # Adjust the size as needed
        icon_anchor=(25, 50),  # Adjust the anchor point as needed
    )
    
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_html, max_width=300),  # Use the HTML popup
        icon=custom_marker_icon,  # Use the custom icon
    ).add_to(m)

# Display the map
m#.save(f'bridges_map_STS7.html')
# Out:
# Number of displayed bridges: 54
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
