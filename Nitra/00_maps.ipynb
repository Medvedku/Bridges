# %%
import pandas as pd

# # Define the file path
# nodes_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
# roads_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Roads_processed.csv"
bridges_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_processed.csv"
bridges_path = r'C:\Users\relia\Documents\GitHub\Bridges\Data\Bridges_processed.csv'
# bridges_selected_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_selected.csv"
# survey_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\surveys\Survey.csv"


# # Load the CSV data into a DataFrame
# df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
# df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')
df_bridges_all = pd.read_csv(bridges_path, encoding='utf-8', delimiter=',')
# df_bridges_sel = pd.read_csv(
#     bridges_selected_path, encoding='utf-8', delimiter=',')
# df_survey = pd.read_csv(survey_path, encoding='utf-8', delimiter=',')

# %%
import pandas as pd

# Define the columns that should be converted to numeric data types
numeric_columns = ['Normálna_zaťažiteľnosť', 'Výhradná_zaťažiteľnosť_t', 'Výnimočná_zaťažiteľnosť_t',
                   'Počet_otvorov', 'Dĺžka_premostenia', 'Dĺžka_nosnej_konštrukcie_m',
                   'Volná_šírka_mosta', 'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
                   'Plocha_mosta_m2', 'n_2012', 'n_2013', 'n_2014', 'n_2015', 'n_2016',
                   'n_2017', 'n_2018', 'n_2019', 'n_2020', 'n_2021', 'n_2022', 'n_2023']

# Convert the selected columns to numeric data types (integers or floats)
for col in numeric_columns:
    df_bridges_all[col] = pd.to_numeric(df_bridges_all[col], errors='coerce')

# Check the data types of the columns after conversion
print(df_bridges_all.dtypes)
# Out:
# ID_mosta                                       object
# Trieda_PK                                      object
# Číslo_PK                                       object
# Most_DC                                        object
# Názov_mosta                                    object
# ID_DC                                          object
# správcovské_číslo                              object
# Zemepisná_dĺžka                               float64
# Zemepisná_šírka                               float64
# Výška                                         float64
# Druh_konštrukcie                               object
# Material                                       object
# Normálna_zaťažiteľnosť                        float64
# Výhradná_zaťažiteľnosť_t                      float64
# Výnimočná_zaťažiteľnosť_t                     float64
# Spôsob_stanovenia                              object
# Predmet_premostenia                            object
# Rok_postavenia                                  int64
# Zaťažovacia_trieda_STN                         object
# Počet_otvorov                                 float64
# Dĺžka_premostenia                             float64
# Dĺžka_nosnej_konštrukcie_m                    float64
# Volná_šírka_mosta                             float64
# Šírka_medzi_obrubami_m                        float64
# Plocha_mosnej_konštrukcie_m2                  float64
# Plocha_mosta_m2                               float64
# Vlastník_úseku                                 object
# Správca_úseku                                  object
# Okres                                          object
# Smer_úseku                                     object
# Typ_úseku                                      object
# Počiatočný_uzol                                object
# Koncový_uzol                                   object
# úsek_ID                                         int64
# úsekové_staničenie_začiatku_DC_m               object
# Kilometrovníkové_staničenie_začiatku_DC_km     object
# Kumulatívne_staničenie_začiatku_DC_km          object
# Poradie                                        object
# Kraj                                           object
# n_2012                                          int64
# n_2013                                          int64
# n_2014                                          int64
# n_2015                                          int64
# n_2016                                          int64
# n_2017                                          int64
# n_2018                                          int64
# n_2019                                          int64
# n_2020                                          int64
# n_2021                                          int64
# n_2022                                          int64
# n_2023                                          int64
# dtype: object

# %%
bridges_Nitra = [
"M57",
"M145",
"M1033",
"M1524",
"M1769",
"M1878",
"M2026",
"M2093",
"M2459",
"M4328",
"M4264",
"M6007",
"M6745",
"M7083"]


# Filter the DataFrame to include only bridges in Nitra
filtered_bridges_Nitra = df_bridges_all[df_bridges_all['ID_mosta'].isin(
    bridges_Nitra)]

# %%
filtered_bridges_Nitra
# Out:
#      ID_mosta          Trieda_PK Číslo_PK          Most_DC  \
# 2146    M2026   cesta II. triedy      511  Dilatačný celok
# 2178    M4264   cesta II. triedy      513  Dilatačný celok
# 2892    M7083   cesta II. triedy      564  Dilatačný celok
# 4270    M6007  cesta III. triedy     1641  Dilatačný celok
# 4632    M6745  cesta III. triedy     1494  Dilatačný celok
# 4657    M4328  cesta III. triedy     1661  Dilatačný celok
# 4730     M145  cesta III. triedy     1474  Dilatačný celok
# 5599    M1033  cesta III. triedy     1506  Dilatačný celok
# 5689    M1524  cesta III. triedy     1621  Dilatačný celok
# 5704      M57  cesta III. triedy     1624  Dilatačný celok
# 5706    M2093  cesta III. triedy     1626  Dilatačný celok
# 5711    M1878  cesta III. triedy     1627  Dilatačný celok
# 5734    M1769  cesta III. triedy     1679  Dilatačný celok
# 5735    M2459  cesta III. triedy     1679  Dilatačný celok
#
#                                    Názov_mosta     ID_DC správcovské_číslo  \
# 2146                Most vo Vrábloch cez potok  M2026.01                26
# 2178        Most nadjazd nad I/51 v kat. Kynek  M4264.01                12
# 2892    Most cez potok Sikenica - Kalinčiakovo  M7083.01                 7
# 4270               Most v katastri Veľký Cetín  M6007.01                 4
# 4632    Most cez rieku Žitava pred obcou Ímeľ.  M6745.01                 2
# 4657             Most cez potok v obci Sľažany  M4328.01                21
# 4730   Most cez odvodňovací kanál pri Kindeši.   M145.01                 4
# 5599             Most cez potok v obci Strekov  M1033.01                 2
# 5689              Most cez potok v obci Hostie  M1524.01                 3
# 5704          Most cez Žitavu v obci  Žitavany    M57.01                 2
# 5706  Most v katastri Čierne Kľačany cez potok  M2093.01                 2
# 5711          Most vo Vrábloch smer Horný Oháj  M1878.01                 4
# 5734                  Most cez potok Nové Sady  M1769.01                 2
# 5735            Most v obci Čab-Sila cez potok  M2459.01                 3
#
#       Zemepisná_dĺžka  Zemepisná_šírka       Výška  ... n_2014 n_2015  n_2016  \
# 2146        18.305002        48.240009  143.874249  ...      5      5       5
# 2178        18.040206        48.319031  161.101250  ...      4      4       4
# 2892        18.660271        48.200216  157.949999  ...      5      5       5
# 4270        18.192625        48.227273  135.239249  ...      5      5       5
# 4632        18.165037        47.864847  113.695749  ...      4      4       4
# 4657        18.326737        48.386844  192.106000  ...      5      5       5
# 4730        18.050431        47.848226  108.768249  ...      5      5       5
# 5599        18.419997        47.898638  126.615250  ...      5      5       5
# 5689        18.438076        48.453374  237.469500  ...      5      5       5
# 5704        18.415086        48.400377  205.574999  ...      4      4       4
# 5706        18.440017        48.320640  226.512499  ...      4      4       4
# 5711        18.312033        48.251588  147.335250  ...      4      4       4
# 5734        17.979117        48.415193  150.432000  ...      4      4       4
# 5735        17.979633        48.404135  149.460999  ...      3      3       3
#
#       n_2017  n_2018 n_2019 n_2020  n_2021 n_2022  n_2023
# 2146       5       5      5      5       5      5       5
# 2178       4       4      4      4       4      4       4
# 2892       5       5      5      5       5      5       5
# 4270       5       5      5      5       6      6       6
# 4632       4       4      4      4       6      6       6
# 4657       5       5      5      5       5      5       5
# 4730       5       5      5      5       5      5       5
# 5599       5       5      5      5       5      5       6
# 5689       5       5      5      5       5      5       5
# 5704       4       4      4      4       5      5       5
# 5706       4       4      4      4       5      5       5
# 5711       4       4      4      4       6      6       6
# 5734       4       4      4      4       5      5       5
# 5735       3       3      3      3       5      5       5
#
# [14 rows x 51 columns]

# %%
filtered_bridges_Nitra.iloc[1]
# Out:
# ID_mosta                                                                   M4264
# Trieda_PK                                                       cesta II. triedy
# Číslo_PK                                                                     513
# Most_DC                                                          Dilatačný celok
# Názov_mosta                                   Most nadjazd nad I/51 v kat. Kynek
# ID_DC                                                                   M4264.01
# správcovské_číslo                                                             12
# Zemepisná_dĺžka                                                        18.040206
# Zemepisná_šírka                                                        48.319031
# Výška                                                                  161.10125
# Druh_konštrukcie                                                         trámová
# Material                                           prefabrikovaný predpätý betón
# Normálna_zaťažiteľnosť                                                      48.0
# Výhradná_zaťažiteľnosť_t                                                   175.0
# Výnimočná_zaťažiteľnosť_t                                                  326.0
# Spôsob_stanovenia                                                        odhadom
# Predmet_premostenia                                           Cestná komunikácia
# Rok_postavenia                                                              1975
# Zaťažovacia_trieda_STN                                                 Nezistený
# Počet_otvorov                                                                3.0
# Dĺžka_premostenia                                                           65.9
# Dĺžka_nosnej_konštrukcie_m                                                   NaN
# Volná_šírka_mosta                                                           19.5
# Šírka_medzi_obrubami_m                                                      17.0
# Plocha_mosnej_konštrukcie_m2                                                 NaN
# Plocha_mosta_m2                                                              NaN
# Vlastník_úseku                                                             NR SK
# Správca_úseku                                                       RSUC NR - NR
# Okres                                                                      Nitra
# Smer_úseku                                                    oba smery trasy CK
# Typ_úseku                                                                    lúč
# Počiatočný_uzol                                                       4521A03405
# Koncový_uzol                                                          4521A03406
# úsek_ID                                                                     1530
# úsekové_staničenie_začiatku_DC_m                                            88.0
# Kilometrovníkové_staničenie_začiatku_DC_km                                30.219
# Kumulatívne_staničenie_začiatku_DC_km                                     28.954
# Poradie                                                                    133.0
# Kraj                                                                       Nitra
# n_2012                                                                         4
# n_2013                                                                         4
# n_2014                                                                         4
# n_2015                                                                         4
# n_2016                                                                         4
# n_2017                                                                         4
# n_2018                                                                         4
# n_2019                                                                         4
# n_2020                                                                         4
# n_2021                                                                         4
# n_2022                                                                         4
# n_2023                                                                         4
# Name: 2178, dtype: object

# %%
import folium
import numpy as np
from folium.plugins import FloatImage


def plot_filtered_bridges(df):
    # Find the average coordinates for the initial map center
    avg_lat = df['Zemepisná_šírka'].mean()
    avg_long = df['Zemepisná_dĺžka'].mean()

    # Create the map with custom tileset
    m = folium.Map(location=[avg_lat, avg_long],
                   zoom_start=8, tiles="Cartodb dark_matter")

    # Colors for the markers
    colors = ["#ff6600", "#0066FF"]

    # Bridge icon
    bridge_icon_url = "https://raw.githubusercontent.com/Medvedku/Assets/cee766454a39d9e86e58fb8d83965a6338c5de37/markers/bridge_marker_Cartodb.svg"

    # Add a marker for each bridge
    for index, row in df.iterrows():
        ic_size = 40
        bridge_icon = folium.CustomIcon(
            icon_image=bridge_icon_url,
            icon_size=(ic_size, ic_size),
            icon_anchor=(ic_size/2, ic_size)
        )

        popup_html = f"<table style='width:400px;'>"
        popup_html += f"<tr><th style='text-align:left;'>Názov mosta:</th><td>{row['Názov_mosta']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Trieda PK:</th><td>{row['Trieda_PK']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Druh konštrukcie:</th><td>{row['Druh_konštrukcie']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Materiál:</th><td>{row['Material']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Rok postavenia:</th><td>{row['Rok_postavenia']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>GPS Coordinates:</th><td>({row['Zemepisná_šírka']:.4f}, {row['Zemepisná_dĺžka']:.4f})</td></tr>"
        popup_html += f"</table>"

        popup = folium.Popup(popup_html, parse_html=False)

        tooltip_html = f"<table style='width:50px;'>"
        tooltip_html += f"<tr><th colspan='2' style='text-align:left;'>Most {row['ID_mosta']}</th></tr>"
        tooltip_html += f"<tr><td style='text-align:left;'>Trieda PK:</td><td>{row['Trieda_PK']}</td></tr>"
        tooltip_html += f"</table>"

        # Add the marker with the custom icon and popup
        folium.Marker(
            [row['Zemepisná_šírka'], row['Zemepisná_dĺžka']],
            icon=bridge_icon,
            popup=popup,
            tooltip=tooltip_html
        ).add_to(m)

    url = ("https://raw.githubusercontent.com/Medvedku/Assets/main/mapy_podpis.svg")
    FloatImage(url, bottom=2, left=93).add_to(m)

    return m


# Usage example (replace 'filtered_bridges' with your filtered DataFrame)
map = plot_filtered_bridges(filtered_bridges_Nitra)
# map.save('filtered_bridges_location.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3149045af61c832d87c65e03384936f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_194f76789d6276b8ecaf6d2603648f2b {
#                         position: absolute;
#                         bottom: 2%;
#                         left: 93%;
#                         }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3149045af61c832d87c65e03384936f7&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_194f76789d6276b8ecaf6d2603648f2b&quot; alt=&quot;float_image&quot;
#                  src=&quot;https://raw.githubusercontent.com/Medvedku/Assets/main/mapy_podpis.svg&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3149045af61c832d87c65e03384936f7 = L.map(
#                 &quot;map_3149045af61c832d87c65e03384936f7&quot;,
#                 {
#                     center: [48.255261322749995, 18.302802645166665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b92b039dd9ad5dcc4b621917366ccfe = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3149045af61c832d87c65e03384936f7);
#
#
#             var marker_9d094edb83aac50f9d548aa99d207a43 = L.marker(
#                 [48.240009283, 18.305001946],
#                 {}
#             ).addTo(map_3149045af61c832d87c65e03384936f7);
#
#
#         var custom_icon_b12cca3b7aad0244bb290efc8404a08d = L.icon({&quot;iconAnchor&quot;: [20.0, 40], &quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/Medvedku/Assets/cee766454a39d9e86e58fb8d83965a6338c5de37/markers/bridge_marker_Cartodb.svg&quot;});
#         marker_9d094edb83aac50f9d548aa99d207a43.setIcon(custom_icon_b12cca3b7aad0244bb290efc8404a08d);
#
#
#         var popup_feea08ae934aa2d5a99f07bc97fe94c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d34b9db12dff7b2ebb3a173db10de54c = $(`&lt;div id=&quot;html_d34b9db12dff7b2ebb3a173db10de54c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&#x27;width:400px;&#x27;&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Názov mosta:&lt;/th&gt;&lt;td&gt;Most vo Vrábloch cez potok&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Trieda PK:&lt;/th&gt;&lt;td&gt;cesta II. triedy&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Druh konštrukcie:&lt;/th&gt;&lt;td&gt;dosková&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Materiál:&lt;/th&gt;&lt;td&gt;monolitický železobetón&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Rok postavenia:&lt;/th&gt;&lt;td&gt;1934&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;GPS Coordinates:&lt;/th&gt;&lt;td&gt;(48.2400, 18.3050)&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_feea08ae934aa2d5a99f07bc97fe94c9.setContent(html_d34b9db12dff7b2ebb3a173db10de54c);
#
#
#
#         marker_9d094edb83aac50f9d548aa99d207a43.bindPopup(popup_feea08ae934aa2d5a99f07bc97fe94c9)
#         ;
#
#
#
#
#             marker_9d094edb83aac50f9d548aa99d207a43.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;table style=&#x27;width:50px;&#x27;&gt;&lt;tr&gt;&lt;th colspan=&#x27;2&#x27; style=&#x27;text-align:left;&#x27;&gt;Most M2026&lt;/th&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td style=&#x27;text-align:left;&#x27;&gt;Trieda PK:&lt;/td&gt;&lt;td&gt;cesta II. triedy&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6dc50a6d563a08bc9af63eaaaaa81a59 = L.marker(
#                 [48.200216341, 18.660270534],
#                 {}
#             ).addTo(map_3149045af61c832d87c65e03384936f7);
#
#
#         var custom_icon_6b9a7848a870416c1ce1e64b595fbbc4 = L.icon({&quot;iconAnchor&quot;: [20.0, 40], &quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/Medvedku/Assets/cee766454a39d9e86e58fb8d83965a6338c5de37/markers/bridge_marker_Cartodb.svg&quot;});
#         marker_6dc50a6d563a08bc9af63eaaaaa81a59.setIcon(custom_icon_6b9a7848a870416c1ce1e64b595fbbc4);
#
#
#         var popup_386bed1fed814a24a7c85197192bd293 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var htm

# %%
df_bridges_all.iloc[46]
# Out:
# ID_mosta                                                                      M6499
# Trieda_PK                                                           cesta I. triedy
# Číslo_PK                                                                         11
# Most_DC                                                             Dilatačný celok
# Názov_mosta                                   Most cez bezmenný potok vo Svrčinovci
# ID_DC                                                                      M6499.01
# správcovské_číslo                                                               200
# Zemepisná_dĺžka                                                           18.781325
# Zemepisná_šírka                                                           49.491616
# Výška                                                                    451.880999
# Druh_konštrukcie                                                            dosková
# Material                                                    monolitický železobetón
# Normálna_zaťažiteľnosť                                                         12.0
# Výhradná_zaťažiteľnosť_t                                                       29.0
# Výnimočná_zaťažiteľnosť_t                                                     187.0
# Spôsob_stanovenia                                                    podľa tabuliek
# Predmet_premostenia                                                       Vodný tok
# Rok_postavenia                                                                 1953
# Zaťažovacia_trieda_STN                                                    Nezistený
# Počet_otvorov                                                                   1.0
# Dĺžka_premostenia                                                               5.0
# Dĺžka_nosnej_konštrukcie_m                                                      NaN
# Volná_šírka_mosta                                                              12.0
# Šírka_medzi_obrubami_m                                                         12.0
# Plocha_mosnej_konštrukcie_m2                                                    NaN
# Plocha_mosta_m2                                                                 NaN
# Vlastník_úseku                                                                  NDS
# Správca_úseku                                                         NDS - SSUR CA
# Okres                                                                         Čadca
# Smer_úseku                                                       oba smery trasy CK
# Typ_úseku                                                         medzikrižovatkový
# Počiatočný_uzol                                                          2613A42900
# Koncový_uzol                                                             2613A43000
# úsek_ID                                                                     1377711
# úsekové_staničenie_začiatku_DC_m                                               69.0
# Kilometrovníkové_staničenie_začiatku_DC_km                                  406.826
# Kumulatívne_staničenie_začiatku_DC_km                                         1.224
# Poradie                                                                         6.0
# Kraj                                                                         Žilina
# n_2012                                                                            4
# n_2013                                                                            4
# n_2014                                                                            4
# n_2015                                                                            4
# n_2016                                                                            4
# n_2017                                                                            4
# n_2018                                                                            4
# n_2019                                                                            4
# n_2020                                                                            4
# n_2021                                                                            4
# n_2022                                                                            4
# n_2023                                                                            4
# Name: 46, dtype: object

# %%
import pandas as pd

# Set the display option to show all columns
pd.set_option('display.max_columns', None)

# Now, print the descriptive statistics
print("Descriptive Statistics for Numerical Features:")
print(filtered_bridges_Nitra.describe())

# Reset the display option to its default value (optional)
pd.reset_option('display.max_columns')
# Out:
# Descriptive Statistics for Numerical Features:
#        Zemepisná_dĺžka  Zemepisná_šírka       Výška  Normálna_zaťažiteľnosť  \
# count        12.000000        12.000000   12.000000               12.000000
# mean         18.302803        48.255261  165.522145               19.166667
# std           0.198230         0.193837   40.075336                8.133358
# min          17.979117        47.864847  113.695749                5.000000
# 25%          18.185728        48.220509  141.715499               14.500000
# 50%          18.319385        48.286114  149.946499               18.000000
# 75%          18.424517        48.401316  195.473250               23.500000
# max          18.660271        48.453374  237.469500               36.000000
#
#        Výhradná_zaťažiteľnosť_t  Výnimočná_zaťažiteľnosť_t  Rok_postavenia  \
# count                 12.000000                  12.000000       12.000000
# mean                  42.083333                 159.750000     1956.750000
# std                   18.627733                 101.810095       15.580436
# min                    9.000000                  30.000000     1931.000000
# 25%                   33.000000                 104.750000     1950.500000
# 50%                   41.500000                 139.000000     1963.500000
# 75%                   46.250000                 176.250000     1965.250000
# max                   87.000000                 404.000000     1974.000000
#
#        Počet_otvorov  Dĺžka_premostenia  Dĺžka_nosnej_konštrukcie_m  \
# count      12.000000          12.000000                         0.0
# mean        1.750000          17.370833                         NaN
# std         0.965307           7.314011                         NaN
# min         1.000000          10.000000                         NaN
# 25%         1.000000          12.550000                         NaN
# 50%         1.000000          14.800000                         NaN
# 75%         3.000000          19.675000                         NaN
# max         3.000000          35.000000                         NaN
#
#        Volná_šírka_mosta  Šírka_medzi_obrubami_m  \
# count          12.000000               12.000000
# mean            8.029167                6.366667
# std             1.227425                0.833757
# min             5.900000                4.600000
# 25%             7.475000                6.325000
# 50%             7.600000                6.500000
# 75%             8.750000                6.700000
# max            10.100000                7.600000
#
#        Plocha_mosnej_konštrukcie_m2  Plocha_mosta_m2       úsek_ID     n_2012  \
# count                           0.0              0.0  1.200000e+01  12.000000
# mean                            NaN              NaN  5.699332e+05   4.416667
# std                             NaN              NaN  3.734585e+05   0.668558
# min                             NaN              NaN  2.857700e+05   3.000000
# 25%                             NaN              NaN  3.470278e+05   4.000000
# 50%                             NaN              NaN  4.888700e+05   4.500000
# 75%                             NaN              NaN  5.091775e+05   5.000000
# max                             NaN              NaN  1.366705e+06   5.000000
#
#           n_2013     n_2014     n_2015     n_2016     n_2017     n_2018  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    4.416667   4.416667   4.416667   4.416667   4.416667   4.416667
# std     0.668558   0.668558   0.668558   0.668558   0.668558   0.668558
# min     3.000000   3.000000   3.000000   3.000000   3.000000   3.000000
# 25%     4.000000   4.000000   4.000000   4.000000   4.000000   4.000000
# 50%     4.500000   4.500000   4.500000   4.500000   4.500000   4.500000
# 75%     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           n_2019     n_2020     n_2021     n_2022     n_2023
# count  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    4.416667   4.416667   5.250000   5.250000   5.333333
# std     0.668558   0.668558   0.452267   0.452267   0.492366
# min     3.000000   3.000000   5.000000   5.000000   5.000000
# 25%     4.000000   4.000000   5.000000   5.000000   5.000000
# 50%     4.500000   4.500000   5.000000   5.000000   5.000000
# 75%     5.000000   5.000000   5.250000   5.250000   6.000000
# max     5.000000   5.000000   6.000000   6.000000   6.000000

# %%
# Define the conditions
condition1 = df_bridges_all['Kraj'] == "Nitra"
condition2 = df_bridges_all['n_2023'] >= 5
condition3 = df_bridges_all['Dĺžka_premostenia'] >= 10
condition4 = (df_bridges_all['Trieda_PK'] == "cesta II. triedy") | (
    df_bridges_all['Trieda_PK'] == "cesta III. triedy")

# Combine the conditions using the & operator for "and" conditions
filtered_bridges_Nitra_suggested = df_bridges_all[condition1 &
                                        condition2 & condition3 & condition4]

# Now, filtered_bridges_Nitra contains the filtered bridges

# %%
filtered_bridges_Nitra_suggested["Material"].value_counts()
# Out:
# Material
# prefabrikovaný predpätý betón    12
# monolitický železobetón          10
# prefabrikovaný železobetón        8
# oceľ -  plnostenná                5
# kameň                             1
# monolitický predpätý betón        1
# Name: count, dtype: int64
