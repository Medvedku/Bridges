# %%
import pandas as pd

# Define the file path
nodes_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Nodes_processed.csv"
roads_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Roads_processed.csv"
bridges_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_processed.csv"
bridges_selected_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\Bridges_selected.csv"
survey_path = r"C:\Users\Doktor\Documents\GitHub\Bridges\Data\surveys\Survey.csv"


# Load the CSV data into a DataFrame
df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')
df_bridges_all = pd.read_csv(bridges_path, encoding='utf-8', delimiter=',')
df_bridges_sel = pd.read_csv(
    bridges_selected_path, encoding='utf-8', delimiter=',')
df_survey = pd.read_csv(survey_path, encoding='utf-8', delimiter=',')
# Out:
# C:\Users\Doktor\AppData\Local\Temp\ipykernel_18504\232746929.py:12: DtypeWarning: Columns (5,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nodes = pd.read_csv(nodes_path, encoding='utf-8', delimiter=',')
# C:\Users\Doktor\AppData\Local\Temp\ipykernel_18504\232746929.py:13: DtypeWarning: Columns (10,11,12,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_roads = pd.read_csv(roads_path, encoding='utf-8', delimiter=',')

# %%
import pandas as pd

# Define the columns that should be converted to numeric data types
numeric_columns = ['Normálna_zaťažiteľnosť', 'Výhradná_zaťažiteľnosť_t', 'Výnimočná_zaťažiteľnosť_t',
                   'Počet_otvorov', 'Dĺžka_premostenia', 'Dĺžka_nosnej_konštrukcie_m',
                   'Volná_šírka_mosta', 'Šírka_medzi_obrubami_m', 'Plocha_mosnej_konštrukcie_m2',
                   'Plocha_mosta_m2', 'n_2012', 'n_2013', 'n_2014', 'n_2015', 'n_2016',
                   'n_2017', 'n_2018', 'n_2019', 'n_2020', 'n_2021', 'n_2022', 'n_2023']

# Convert the selected columns to numeric data types (integers or floats)
for col in numeric_columns:
    df_bridges_all[col] = pd.to_numeric(df_bridges_all[col], errors='coerce')

# Check the data types of the columns after conversion
print(df_bridges_all.dtypes)
# Out:
# ID_mosta                                       object
# Trieda_PK                                      object
# Číslo_PK                                       object
# Most_DC                                        object
# Názov_mosta                                    object
# ID_DC                                          object
# správcovské_číslo                              object
# Zemepisná_dĺžka                               float64
# Zemepisná_šírka                               float64
# Výška                                         float64
# Druh_konštrukcie                               object
# Material                                       object
# Normálna_zaťažiteľnosť                        float64
# Výhradná_zaťažiteľnosť_t                      float64
# Výnimočná_zaťažiteľnosť_t                     float64
# Spôsob_stanovenia                              object
# Predmet_premostenia                            object
# Rok_postavenia                                  int64
# Zaťažovacia_trieda_STN                         object
# Počet_otvorov                                 float64
# Dĺžka_premostenia                             float64
# Dĺžka_nosnej_konštrukcie_m                    float64
# Volná_šírka_mosta                             float64
# Šírka_medzi_obrubami_m                        float64
# Plocha_mosnej_konštrukcie_m2                  float64
# Plocha_mosta_m2                               float64
# Vlastník_úseku                                 object
# Správca_úseku                                  object
# Okres                                          object
# Smer_úseku                                     object
# Typ_úseku                                      object
# Počiatočný_uzol                                object
# Koncový_uzol                                   object
# úsek_ID                                         int64
# úsekové_staničenie_začiatku_DC_m               object
# Kilometrovníkové_staničenie_začiatku_DC_km     object
# Kumulatívne_staničenie_začiatku_DC_km          object
# Poradie                                        object
# Kraj                                           object
# n_2012                                          int64
# n_2013                                          int64
# n_2014                                          int64
# n_2015                                          int64
# n_2016                                          int64
# n_2017                                          int64
# n_2018                                          int64
# n_2019                                          int64
# n_2020                                          int64
# n_2021                                          int64
# n_2022                                          int64
# n_2023                                          int64
# dtype: object

# %%
bridges_Nitra = ["M57", "M145", "M741", "M1033", "M1524", "M1769",
                 "M1878", "M2026", "M2093", "M2459", "M4264", "M4328", 
                 "M5728", "M6007", "M6174", "M6734", "M6745", "M7083",
                 "M7383"]

# Filter the DataFrame to include only bridges in Nitra
filtered_bridges_Nitra = df_bridges_all[df_bridges_all['ID_mosta'].isin(
    bridges_Nitra)]

# %%
bridges_Nitra = ["M7383"]

# Filter the DataFrame to include only bridges in Nitra
filtered_bridges_Nitra = df_bridges_all[df_bridges_all['ID_mosta'].isin(
    bridges_Nitra)]

import folium

def plot_filtered_bridges(df, gdf):
    # Find the average coordinates for the initial map center
    avg_lat = df['Zemepisná_šírka'].mean()
    avg_long = df['Zemepisná_dĺžka'].mean()

    avg_lat = 48.25
    avg_long = 18

    # Create the map with custom tileset
    m = folium.Map(location=[avg_lat, avg_long],
                   zoom_start=9, tiles="Cartodb positron")

    # Colors for the markers
    colors = ["#ff6600", "#0066FF"]

    # Bridge icon
    bridge_icon_url = "https://raw.githubusercontent.com/Medvedku/Assets/main/markers/bridge_marker_Cartodb_orng.svg"

    # Add a marker for each bridge
    for index, row in df.iterrows():
        ic_size = 80
        bridge_icon = folium.CustomIcon(
            icon_image=bridge_icon_url,
            icon_size=(ic_size, ic_size),
            icon_anchor=(ic_size/2, ic_size)
        )

        popup_html = f"<table style='width:400px;'>"
        popup_html += f"<tr><th style='text-align:left;'>Názov mosta:</th><td>{row['Názov_mosta']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Trieda PK:</th><td>{row['Trieda_PK']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Druh konštrukcie:</th><td>{row['Druh_konštrukcie']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Materiál:</th><td>{row['Material']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Rok postavenia:</th><td>{row['Rok_postavenia']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>GPS Coordinates:</th><td>({row['Zemepisná_šírka']:.4f}, {row['Zemepisná_dĺžka']:.4f})</td></tr>"
        popup_html += f"</table>"

        popup = folium.Popup(popup_html, parse_html=False)

        tooltip_html = f"<table style='width:50px;'>"
        tooltip_html += f"<tr><th colspan='2' style='text-align:left;'>Most {row['ID_mosta']}</th></tr>"
        tooltip_html += f"<tr><td style='text-align:left;'>Trieda PK:</td><td>{row['Trieda_PK']}</td></tr>"
        tooltip_html += f"</table>"

        # Add the marker with the custom icon and popup
        folium.Marker(
            [row['Zemepisná_šírka'], row['Zemepisná_dĺžka']],
            icon=bridge_icon,
            popup=popup,
            tooltip=tooltip_html
        ).add_to(m)

    # Filter the GeoDataFrame to include only the Nitra Region
    nitra_region_gdf = gdf[gdf['NM4'] == 'Nitriansky']

    # Define custom style for the Nitra Region polygon
    def style_function(x): return {
        'fillColor': '#FF6600', 'color': '#FF6600', 'weight': 2}

    # Add the boundaries of the Nitra Region to the map with the custom style
    folium.GeoJson(nitra_region_gdf,
                   name='Nitra Region Boundaries',
                   style_function=style_function).add_to(m)

    return m

# Usage example (replace 'filtered_bridges' with your filtered DataFrame)
map = plot_filtered_bridges(filtered_bridges_Nitra, gdf)
map.save('filtered_bridges_with_nitra_region.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6a5fca8ffef8524c00c88d07c60c309 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6a5fca8ffef8524c00c88d07c60c309&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6a5fca8ffef8524c00c88d07c60c309 = L.map(
#                 &quot;map_b6a5fca8ffef8524c00c88d07c60c309&quot;,
#                 {
#                     center: [48.25, 18.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f11e4e78062c080b5d26d5abec05853c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6a5fca8ffef8524c00c88d07c60c309);
#
#
#             var marker_2e0e378a2e3e95ceaf623127d8b7752c = L.marker(
#                 [48.156511851, 18.877518719],
#                 {}
#             ).addTo(map_b6a5fca8ffef8524c00c88d07c60c309);
#
#
#         var custom_icon_15ca8ad91cc9887beca4dc985ea16448 = L.icon({&quot;iconAnchor&quot;: [40.0, 80], &quot;iconSize&quot;: [80, 80], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/Medvedku/Assets/main/markers/bridge_marker_Cartodb_orng.svg&quot;});
#         marker_2e0e378a2e3e95ceaf623127d8b7752c.setIcon(custom_icon_15ca8ad91cc9887beca4dc985ea16448);
#
#
#         var popup_85f324fa7e894247843d5a8dfa8a7d3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c81b0c1e5bdcdf0fe7d5a78a15e738f = $(`&lt;div id=&quot;html_9c81b0c1e5bdcdf0fe7d5a78a15e738f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&#x27;width:400px;&#x27;&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Názov mosta:&lt;/th&gt;&lt;td&gt;Most cez potok Štiavnička - Hokovce&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Trieda PK:&lt;/th&gt;&lt;td&gt;cesta III. triedy&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Druh konštrukcie:&lt;/th&gt;&lt;td&gt;trámová&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Materiál:&lt;/th&gt;&lt;td&gt;prefabrikovaný predpätý betón&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Rok postavenia:&lt;/th&gt;&lt;td&gt;1959&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;GPS Coordinates:&lt;/th&gt;&lt;td&gt;(48.1565, 18.8775)&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_85f324fa7e894247843d5a8dfa8a7d3e.setContent(html_9c81b0c1e5bdcdf0fe7d5a78a15e738f);
#
#
#
#         marker_2e0e378a2e3e95ceaf623127d8b7752c.bindPopup(popup_85f324fa7e894247843d5a8dfa8a7d3e)
#         ;
#
#
#
#
#             marker_2e0e378a2e3e95ceaf623127d8b7752c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;table style=&#x27;width:50px;&#x27;&gt;&lt;tr&gt;&lt;th colspan=&#x27;2&#x27; style=&#x27;text-align:left;&#x27;&gt;Most M7383&lt;/th&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td style=&#x27;text-align:left;&#x27;&gt;Trieda PK:&lt;/td&gt;&lt;td&gt;cesta III. triedy&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         function geo_json_864e6e12ac055af0253344562b3ca242_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF6600&quot;, &quot;fillColor&quot;: &quot;#FF6600&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_864e6e12ac055af0253344562b3ca242_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_864e6e12ac055af0253344562b3ca242 = L.geoJson(null, {
#                 onEachFeature: geo_json_864e6e12ac055af0253344562b3ca242_onEachFeature,
#
#                 style: geo_json_864e6e12ac055af0253344562b3ca242_styler,
#         });
#
#         function geo_json_864e6e12ac055af0253344562b3ca242_add (data) {
#             geo_json_864e6e12ac055af0253344562b3ca242
#                 .addData(data)
#                 .addTo(map_b6a5fca8ffef8524c00c88d07c60c309);
#         }
#             geo_json_864e6e12ac055af0253344562b3ca242_add({&quot;bbox&quot;: [17.705346434761644, 47.731185629632975, 19.072035463191334, 48.71442853265028], &quot;features&quot;: [{&quot;bbox&quot;: [17.705346434761644, 47.731185629632975, 19.072035463191334, 48.71442853265028], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[18.006700180607655, 48.71389965226654], [18.01242721353867, 48.71221426380499], [18.017455654782246, 48.71402146970975], [18.01979624136846, 48.7133

# %%
filtered_bridges_Nitra.iloc[0]
# Out:
# ID_mosta                                                           M2026
# Trieda_PK                                               cesta II. triedy
# Číslo_PK                                                             511
# Most_DC                                                  Dilatačný celok
# Názov_mosta                                   Most vo Vrábloch cez potok
# ID_DC                                                           M2026.01
# správcovské_číslo                                                     26
# Zemepisná_dĺžka                                                18.305002
# Zemepisná_šírka                                                48.240009
# Výška                                                         143.874249
# Druh_konštrukcie                                                 dosková
# Material                                         monolitický železobetón
# Normálna_zaťažiteľnosť                                              23.0
# Výhradná_zaťažiteľnosť_t                                            44.0
# Výnimočná_zaťažiteľnosť_t                                          140.0
# Spôsob_stanovenia                                                odhadom
# Predmet_premostenia                                            Vodný tok
# Rok_postavenia                                                      1934
# Zaťažovacia_trieda_STN                                         Nezistený
# Počet_otvorov                                                        1.0
# Dĺžka_premostenia                                                   13.0
# Dĺžka_nosnej_konštrukcie_m                                           NaN
# Volná_šírka_mosta                                                    7.5
# Šírka_medzi_obrubami_m                                               6.1
# Plocha_mosnej_konštrukcie_m2                                         NaN
# Plocha_mosta_m2                                                      NaN
# Vlastník_úseku                                                     NR SK
# Správca_úseku                                               RSUC NR - NR
# Okres                                                              Nitra
# Smer_úseku                                            oba smery trasy CK
# Typ_úseku                                              medzikrižovatkový
# Počiatočný_uzol                                               4521A23500
# Koncový_uzol                                                  4521A23600
# úsek_ID                                                           509172
# úsekové_staničenie_začiatku_DC_m                                    45.0
# Kilometrovníkové_staničenie_začiatku_DC_km                        48.123
# Kumulatívne_staničenie_začiatku_DC_km                             47.999
# Poradie                                                            163.0
# Kraj                                                               Nitra
# n_2012                                                                 5
# n_2013                                                                 5
# n_2014                                                                 5
# n_2015                                                                 5
# n_2016                                                                 5
# n_2017                                                                 5
# n_2018                                                                 5
# n_2019                                                                 5
# n_2020                                                                 5
# n_2021                                                                 5
# n_2022                                                                 5
# n_2023                                                                 5
# Name: 2146, dtype: object

# %%
import geopandas as gpd
# Replace the file path with your actual file path
file_path = r'C:\Users\Doktor\Documents\GitHub\Bridges\Nitra\regions_epsg_4326.geojson'
# Load the GeoJSON file into a GeoDataFrame
gdf = gpd.read_file(file_path)
# Display the first few rows of the GeoDataFrame
# gdf.head()

# %%
import folium


def plot_filtered_bridges(df, gdf):
    # Find the average coordinates for the initial map center
    avg_lat = df['Zemepisná_šírka'].mean()
    avg_long = df['Zemepisná_dĺžka'].mean()

    # Create the map with custom tileset
    m = folium.Map(location=[avg_lat, avg_long],
                   zoom_start=8, tiles="Cartodb positron")

    # Colors for the markers
    colors = ["#ff6600", "#0066FF"]

    # Bridge icon
    bridge_icon_url = "https://raw.githubusercontent.com/Medvedku/Assets/main/markers/bridge_marker_Cartodb_orng.svg"

    # Add a marker for each bridge
    for index, row in df.iterrows():
        ic_size = 40
        bridge_icon = folium.CustomIcon(
            icon_image=bridge_icon_url,
            icon_size=(ic_size, ic_size),
            icon_anchor=(ic_size/2, ic_size)
        )

        popup_html = f"<table style='width:400px;'>"
        popup_html += f"<tr><th style='text-align:left;'>Názov mosta:</th><td>{row['Názov_mosta']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Trieda PK:</th><td>{row['Trieda_PK']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Druh konštrukcie:</th><td>{row['Druh_konštrukcie']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Materiál:</th><td>{row['Material']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>Rok postavenia:</th><td>{row['Rok_postavenia']}</td></tr>"
        popup_html += f"<tr><th style='text-align:left;'>GPS Coordinates:</th><td>({row['Zemepisná_šírka']:.4f}, {row['Zemepisná_dĺžka']:.4f})</td></tr>"
        popup_html += f"</table>"

        popup = folium.Popup(popup_html, parse_html=False)

        tooltip_html = f"<table style='width:50px;'>"
        tooltip_html += f"<tr><th colspan='2' style='text-align:left;'>Most {row['ID_mosta']}</th></tr>"
        tooltip_html += f"<tr><td style='text-align:left;'>Trieda PK:</td><td>{row['Trieda_PK']}</td></tr>"
        tooltip_html += f"</table>"

        # Add the marker with the custom icon and popup
        folium.Marker(
            [row['Zemepisná_šírka'], row['Zemepisná_dĺžka']],
            icon=bridge_icon,
            popup=popup,
            tooltip=tooltip_html
        ).add_to(m)

    # Filter the GeoDataFrame to include only the Nitra Region
    nitra_region_gdf = gdf[gdf['NM4'] == 'Nitriansky']

    # Define custom style for the Nitra Region polygon
    def style_function(x): return {
        'fillColor': '#FF6600', 'color': '#FF6600', 'weight': 2}

    # Add the boundaries of the Nitra Region to the map with the custom style
    folium.GeoJson(nitra_region_gdf,
                   name='Nitra Region Boundaries',
                   style_function=style_function).add_to(m)

    return m


# Usage example (replace 'filtered_bridges' with your filtered DataFrame)
map = plot_filtered_bridges(filtered_bridges_Nitra, gdf)
# map.save('filtered_bridges_with_nitra_region.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_755168927e4a226013c4c43fe7704b2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_755168927e4a226013c4c43fe7704b2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_755168927e4a226013c4c43fe7704b2a = L.map(
#                 &quot;map_755168927e4a226013c4c43fe7704b2a&quot;,
#                 {
#                     center: [47.848226196, 18.050430708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f29b94493fe283b7871f80f4fdbb6904 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_755168927e4a226013c4c43fe7704b2a);
#
#
#             var marker_35ba1b0a14d57e704660619e3e5a96dc = L.marker(
#                 [47.848226196, 18.050430708],
#                 {}
#             ).addTo(map_755168927e4a226013c4c43fe7704b2a);
#
#
#         var custom_icon_f2fb5375b29b573b98c23ac23de5c589 = L.icon({&quot;iconAnchor&quot;: [20.0, 40], &quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/Medvedku/Assets/main/markers/bridge_marker_Cartodb_orng.svg&quot;});
#         marker_35ba1b0a14d57e704660619e3e5a96dc.setIcon(custom_icon_f2fb5375b29b573b98c23ac23de5c589);
#
#
#         var popup_f693b96558c98b347c44c3117a024989 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0789e6be9c6b3e24dd2054110407032e = $(`&lt;div id=&quot;html_0789e6be9c6b3e24dd2054110407032e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&#x27;width:400px;&#x27;&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Názov mosta:&lt;/th&gt;&lt;td&gt;Most cez odvodňovací kanál pri Kindeši.&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Trieda PK:&lt;/th&gt;&lt;td&gt;cesta III. triedy&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Druh konštrukcie:&lt;/th&gt;&lt;td&gt;dosková&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Materiál:&lt;/th&gt;&lt;td&gt;prefabrikovaný železobetón&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;Rok postavenia:&lt;/th&gt;&lt;td&gt;1968&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th style=&#x27;text-align:left;&#x27;&gt;GPS Coordinates:&lt;/th&gt;&lt;td&gt;(47.8482, 18.0504)&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_f693b96558c98b347c44c3117a024989.setContent(html_0789e6be9c6b3e24dd2054110407032e);
#
#
#
#         marker_35ba1b0a14d57e704660619e3e5a96dc.bindPopup(popup_f693b96558c98b347c44c3117a024989)
#         ;
#
#
#
#
#             marker_35ba1b0a14d57e704660619e3e5a96dc.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;table style=&#x27;width:50px;&#x27;&gt;&lt;tr&gt;&lt;th colspan=&#x27;2&#x27; style=&#x27;text-align:left;&#x27;&gt;Most M145&lt;/th&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td style=&#x27;text-align:left;&#x27;&gt;Trieda PK:&lt;/td&gt;&lt;td&gt;cesta III. triedy&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         function geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF6600&quot;, &quot;fillColor&quot;: &quot;#FF6600&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c = L.geoJson(null, {
#                 onEachFeature: geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c_onEachFeature,
#
#                 style: geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c_styler,
#         });
#
#         function geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c_add (data) {
#             geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c
#                 .addData(data)
#                 .addTo(map_755168927e4a226013c4c43fe7704b2a);
#         }
#             geo_json_cc34312f61ba3ee662cf0e3c3a9bc84c_add({&quot;bbox&quot;: [17.705346434761644, 47.731185629632975, 19.072035463191334, 48.71442853265028], &quot;features&quot;: [{&quot;bbox&quot;: [17.705346434761644, 47.731185629632975, 19.072035463191334, 48.71442853265028], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[18.006700180607655, 48.71389965226654], [18.01242721353867, 48.71221426380499], [18.017455654782246, 48.71402146970975], [18.01979624
